# %% [markdown]
# ## Importing data and fixing column names and types

# %% [markdown]
# ### Importing dataset from kaggle

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("dataset/train.csv",encoding='unicode_escape', usecols=['text', 'sentiment'])
df.rename(columns={'text': 'comment'}, inplace=True)

# %%
df
# Out:
#                                                  comment sentiment
# 0                    I`d have responded, if I were going   neutral
# 1          Sooo SAD I will miss you here in San Diego!!!  negative
# 2                              my boss is bullying me...  negative
# 3                         what interview! leave me alone  negative
# 4       Sons of ****, why couldn`t they put them on t...  negative
# ...                                                  ...       ...
# 27476   wish we could come see u on Denver  husband l...  negative
# 27477   I`ve wondered about rake to.  The client has ...  negative
# 27478   Yay good for both of you. Enjoy the break - y...  positive
# 27479                         But it was worth it  ****.  positive
# 27480     All this flirting going on - The ATG smiles...   neutral
#
# [27481 rows x 2 columns]

# %%
df = df.dropna()

# %%
df.loc[:, 'sentiment'] = df['sentiment'].map({"positive":1, "negative":-1, "neutral":0})

# %%
df
# Out:
#                                                  comment sentiment
# 0                    I`d have responded, if I were going         0
# 1          Sooo SAD I will miss you here in San Diego!!!        -1
# 2                              my boss is bullying me...        -1
# 3                         what interview! leave me alone        -1
# 4       Sons of ****, why couldn`t they put them on t...        -1
# ...                                                  ...       ...
# 27476   wish we could come see u on Denver  husband l...        -1
# 27477   I`ve wondered about rake to.  The client has ...        -1
# 27478   Yay good for both of you. Enjoy the break - y...         1
# 27479                         But it was worth it  ****.         1
# 27480     All this flirting going on - The ATG smiles...         0
#
# [27480 rows x 2 columns]

# %% [markdown]
# ## Train, Test, Split

# %%
# !pip install numpy==1.26.4

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df[['comment']], df[['sentiment']], random_state=25, test_size=0.2)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/prashant-maurya/anaconda3/lib/python3.12/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/prashant-maurya/anaconda3/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/prashant-maurya/anaconda3/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "/home/prashant-maurya/anaconda3/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/home/prashant-maurya/anaconda3/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/home/prashant-maurya/anaconda3/lib/python3.12/asyncio/base_events.py", line 1987, in _run_once
#     handle._run()
#   File "/home/prashant-maurya/anaconda3/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/prashant-maurya/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "/home/prashant-maurya/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "/home/prashant-maurya/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "/home/prashant-maurya/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/home/prashant-maurya/anaconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "/home/prashant-maurya/anaconda3/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/prashant-maurya/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/prashant-maurya/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/prashant-maurya/anaconda3/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/prashant-maurya/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/prashant-maurya/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/prashant-maurya/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_37527/2329622375.py", line 1, in <module>
#     from sklearn.model_selection import train_test_split
#   File "/home/prashant-maurya/anaconda3/lib/python3.12/site-packages/sklearn/__init__.py", line 87, in <module>
#     from .base import clone
#   File "/home/prashant-maurya/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils import _IS_32BIT
#   File "/home/prashant-maurya/anaconda3/lib/python3.12/site-packages/sklearn/utils/__init__.py", line 16, in <module>
#     from scipy.sparse import issparse
#   File "/home/prashant-maurya/anaconda3/lib/python3.12/site-packages/scipy/sparse/__init__.py", line 295, in <module>
#     from ._csr import *
#   File "/home/prashant-maurya/anaconda3/lib/python3.12/site-packages/scipy/sparse/_csr.py", line 11, in <module>
#     from ._sparsetools import (csr_tocsc, csr_tobsr, csr_count_blocks,
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/anaconda3/lib/python3.12/site-packages/numpy/core/_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#       2 x_train, x_test, y_train, y_test = train_test_split(df[['comment']], df[['sentiment']], random_state=25, test_size=0.2)
#
# File ~/anaconda3/lib/python3.12/site-packages/sklearn/__init__.py:87
#      73     # We are not importing the rest of scikit-learn during the build
#      74     # process, as it may not be compiled yet
#      75 else:
#    (...)
#      81     # later is linked to the OpenMP runtime to make it possible to introspect
#      82     # it and importing it first would fail if the OpenMP dll cannot be found.
#      83     from . import (
#      84         __check_build,  # noqa: F401
#      85         _distributor_init,  # noqa: F401
#      86     )
# ---> 87     from .base import clone
#      88     from .utils._show_versions import show_versions
#      90     __all__ = [
#      91         "calibration",
#      92         "cluster",
#    (...)
#     133         "show_versions",
#     134     ]
#
# File ~/anaconda3/lib/python3.12/site-packages/sklearn/base.py:19
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils import _IS_32BIT
#      20 from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#      21 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#
# File ~/anaconda3/lib/python3.12/site-packages/sklearn/utils/__init__.py:16
#      13 from itertools import compress, islice
#      15 import numpy as np
# ---> 16 from scipy.sparse import issparse
#      18 from .. import get_config
#      19 from ..exceptions import DataConversionWarning
#
# File ~/anaconda3/lib/python3.12/site-packages/scipy/sparse/__init__.py:295
#     292 import warnings as _warnings
#     294 from ._base import *
# --> 295 from ._csr import *
#     296 from ._csc import *
#     297 from ._lil import *
#
# File ~/anaconda3/lib/python3.12/site-packages/scipy/sparse/_csr.py:11
#       9 from ._matrix import spmatrix
#      10 from ._base import _spbase, sparray
# ---> 11 from ._sparsetools import (csr_tocsc, csr_tobsr, csr_count_blocks,
#      12                            get_csr_submatrix)
#      13 from ._sputils import upcast
#      15 from ._compressed import _cs_matrix
#
# ImportError: numpy.core.multiarray failed to import

# %%
x_train
# Out:
#                                                  comment
# 15707  exhausting day. And more to come tomorrow! Cit...
# 21368                 Got Six Feet Under series 1 on DVD
# 392    Just discovered a shortcoming of Gravity. When...
# 23187  I was so hype about it being Friday & it raini...
# 19983  trying to draw some manga/anime for our new we...
# ...                                                  ...
# 24832    My class will be at Chem Sc building. Will s...
# 2935            The sun is shining and I`m stuck in work
# 26768          i`m bored : hope your wlan will go today!
# 6619    Just wanted to point out that on Youtube, you...
# 24895             havin fun? x btw isnt it bowling? ****
#
# [21984 rows x 1 columns]

# %%
x_test
# Out:
#                                                  comment
# 18443  Gdnight Tweeters (: Night  sleep tight and don...
# 11402  is in the middle of the Irish sea... with abse...
# 23354                                     More homework.
# 20232  sad day, redskins release Jansen   Best wishes...
# 22616   Spring cleaning episode 2....do I really have to
# ...                                                  ...
# 9994                                           im 16 too
# 5383       sad day!!!!! Love you MaÃ¯Â¿Â½ (8 years ago!)
# 19121               House hunting for next year= No FUN!
# 4409   There`s just something about a sexy blonde ***...
# 2557    Workin ur crazy sched. has to be tiring..its ...
#
# [5496 rows x 1 columns]

# %% [markdown]
# ### Making dataframe insted of printing

# %% [markdown]
# ## Text Preprocessing

# %% [markdown]
# ### Lower Casing

# %%
x_train['comment'][391].lower()
# Out:
# 'brainfreeze'

# %%
x_train['comment'].str.lower()
# Out:
# 15707    exhausting day. and more to come tomorrow! cit...
# 21368                   got six feet under series 1 on dvd
# 392      just discovered a shortcoming of gravity. when...
# 23187    i was so hype about it being friday & it raini...
# 19983    trying to draw some manga/anime for our new we...
#                                ...
# 24832      my class will be at chem sc building. will s...
# 2935              the sun is shining and i`m stuck in work
# 26768            i`m bored : hope your wlan will go today!
# 6619      just wanted to point out that on youtube, you...
# 24895               havin fun? x btw isnt it bowling? ****
# Name: comment, Length: 21984, dtype: object

# %%
x_train['comment'] = x_train['comment'].str.lower()
x_test['comment'] = x_test['comment'].str.lower()

# %% [markdown]
# ### Convert html unescape characters

# %%
text1 = "Didn&#39;t catch it earlier but man at start of video said Punkey Brewster. Now that is some 80s shit, when I grew up. Felt good hearing that as I missed it in earlier viewings of this video"
text2 = "so this is great! one thing I am missing is why keep using &#39;bro&#39; &amp; &#39;brother&#39;  just does not fit!!"
text3 = "Action after sipping the wine &quot;it&#39;s gentle like a kiss, no tongue&quot;"
text4 = "Part I &quot;Le Retour&quot;, no S, shall ask for correction!"
text5 = "I&#39;M WATCHING THIS WHILE I&#39;M EATING.. I&#39;M STILL HUNGRY"

# %%
import html

# %%
def convert_html_unescapes(text):
  return html.unescape(text)

# %%
print(convert_html_unescapes(text1))
print(convert_html_unescapes(text2))
print(convert_html_unescapes(text3))
print(convert_html_unescapes(text4))
print(convert_html_unescapes(text5))
# Out:
# Didn't catch it earlier but man at start of video said Punkey Brewster. Now that is some 80s shit, when I grew up. Felt good hearing that as I missed it in earlier viewings of this video
# so this is great! one thing I am missing is why keep using 'bro' & 'brother'  just does not fit!!
# Action after sipping the wine "it's gentle like a kiss, no tongue"
# Part I "Le Retour", no S, shall ask for correction!
# I'M WATCHING THIS WHILE I'M EATING.. I'M STILL HUNGRY

# %%
x_train['comment'].apply(convert_html_unescapes)
# Out:
# 15707    exhausting day. and more to come tomorrow! cit...
# 21368                   got six feet under series 1 on dvd
# 392      just discovered a shortcoming of gravity. when...
# 23187    i was so hype about it being friday & it raini...
# 19983    trying to draw some manga/anime for our new we...
#                                ...
# 24832      my class will be at chem sc building. will s...
# 2935              the sun is shining and i`m stuck in work
# 26768            i`m bored : hope your wlan will go today!
# 6619      just wanted to point out that on youtube, you...
# 24895               havin fun? x btw isnt it bowling? ****
# Name: comment, Length: 21984, dtype: object

# %%
x_train['comment'] = x_train['comment'].apply(convert_html_unescapes)
x_test['comment'] = x_test['comment'].apply(convert_html_unescapes)

# %% [markdown]
# ### HTML tags removal

# %%
x_train['comment'][5]
# Out:
# 'http://www.dothebouncy.com/smf - some shameless plugging for the best rangers forum on earth'

# %%
import re
def remove_html_tags(text):
  pattern = re.compile('<.*?>')
  return pattern.sub(r' ',text)

# %%
text = '<html> hdsahjd</html>quoi sevin!?<br>le poulet j&#39;ai criend! here😂 <a href="https://www.youtube.com/watch?v=-GJgqIJsTME&amp;t=98">1:38</a>. Great episode!'

# %%
remove_html_tags(text)
# Out:
# '  hdsahjd quoi sevin!? le poulet j&#39;ai criend! here😂  1:38 . Great episode!'

# %%
x_train['comment'].apply(remove_html_tags)
# Out:
# 15707    exhausting day. and more to come tomorrow! cit...
# 21368                   got six feet under series 1 on dvd
# 392      just discovered a shortcoming of gravity. when...
# 23187    i was so hype about it being friday & it raini...
# 19983    trying to draw some manga/anime for our new we...
#                                ...
# 24832      my class will be at chem sc building. will s...
# 2935              the sun is shining and i`m stuck in work
# 26768            i`m bored : hope your wlan will go today!
# 6619      just wanted to point out that on youtube, you...
# 24895               havin fun? x btw isnt it bowling? ****
# Name: comment, Length: 21984, dtype: object

# %%
x_train['comment'] = x_train['comment'].apply(remove_html_tags)

# %%
x_test['comment'] = x_test['comment'].apply(remove_html_tags)

# %% [markdown]
# ### Remove URLs

# %%
text1 = 'Check out our e-shop http://www.google.com/kaggle fhsdjkfgs'
text2 = 'Check out our e-shop http://www.google.com ghf'
text3 = 'Check out our e-shop www.google.com/kaggle'
text4 = 'Check out our e-shop https://www.google.com'
text5 = 'Check out our e-shop https://www.google.com/kaggle/ gfgfg'
text6 = 'Check out our e-shop http://www.google.com/kaggle/'

# %%
text4
# Out:
# 'Check out our e-shop https://www.google.com'

# %%
def remove_URLs(text):
  pattern = re.compile(r'https?://\S+|www\.\S+')
  return pattern.sub(r' ', text)

# %%
print(remove_URLs(text1))
print(remove_URLs(text2))
print(remove_URLs(text3))
print(remove_URLs(text4))
print(remove_URLs(text5))
print(remove_URLs(text6))
# Out:
# Check out our e-shop   fhsdjkfgs
# Check out our e-shop   ghf
# Check out our e-shop
# Check out our e-shop
# Check out our e-shop   gfgfg
# Check out our e-shop

# %%
x_train['comment'] = x_train['comment'].apply(remove_URLs)
x_test['comment'] = x_test['comment'].apply(remove_URLs)

# %% [markdown]
# ### Replace ` to '

# %%
x_train.loc[:,'comment'] = x_train['comment'].str.replace('`', "'")
x_test.loc[:,'comment'] = x_test['comment'].str.replace('`', "'")

# %% [markdown]
# ### Remove chat words

# %%
chat_words = {'AFAIK':'As Far As I Know',
'AFK':'Away From Keyboard',
'ASAP':'As Soon As Possible',
'ATK':'At The Keyboard',
'ATM':'At The Moment',
'A3':'Anytime, Anywhere, Anyplace',
'BAK':'Back At Keyboard',
'BBL':'Be Back Later',
'BBS':'Be Back Soon',
'BFN':'Bye For Now',
'B4N':'Bye For Now',
'BRB':'Be Right Back',
'BRT':'Be Right There',
'BTW':'By The Way',
'B4':'Before',
'B4N':'Bye For Now',
'CU':'See You',
'CUL8R':'See You Later',
'CYA':'See You',
'FAQ':'Frequently Asked Questions',
'FC':'Fingers Crossed',
'FWIW':"For What It's Worth",
'FYI':'For Your Information',
'GAL':'Get A Life',
'GG':'Good Game',
'GN':'Good Night',
'GMTA':'Great Minds Think Alike',
'GR8':'Great!',
'G9':'Genius',
'IC':'I See',
'ICQ':'I Seek you (also a chat program)',
'ILU':'I Love You',
'IMHO':'In My Humble Opinion',
'IMO':'In My Opinion',
'IOW':'In Other Words',
'IRL':'In Real Life',
'KISS':'Keep It Simple, Stupid',
'LDR':'Long Distance Relationship',
'LMAO':'Laugh My A.. Off',
'LOL':'Laughing Out Loud',
'LTNS':'Long Time No See',
'L8R':'Later',
'MTE':'My Thoughts Exactly',
'M8':'Mate',
'NRN':'No Reply Necessary',
'OIC':'Oh I See',
'PITA':'Pain In The Ass',
'PRT':'Party',
'PRW':'Parents Are Watching',
'QPSA?':'Que Pasa?',
'ROFL':'Rolling On The Floor Laughing',
'ROFLOL':'Rolling On The Floor Laughing Out Loud',
'ROTFLMAO':'Rolling On The Floor Laughing My Ass Off',
'SK8':'Skate',
'STATS':'Your sex and age',
'ASL':'Age, Sex, Location',
'THX':'Thank You',
'TTFN':'Ta-Ta For Now!',
'TTYL':'Talk To You Later',
'U':'You',
'U2':'You Too',
'U4E':'Yours For Ever',
'WB':'Welcome Back',
'WTF':'What The Fuck',
'WTG':'Way To Go!',
'WUF':'Where Are You From?',
'W8':'Wait...',
'7K':'Sick Laugher',
'TFW':'That feeling when. TFW internet slang often goes in a caption to an image.',
'MFW':'My face when',
'MRW':'My reaction when',
'IFYP':'I feel your pain',
'LOL':'Laughing out loud',
'TNTL':'Trying not to laugh',
'JK':'Just kidding',
'IDC':"I don't care",
'ILY':'I love you',
'IMU':'I miss you',
'ADIH':'Another day in hell',
'IDC':"I don't care",
'ZZZ':'Sleeping, bored, tired',
'WYWH':'Wish you were here',
'TIME':'Tears in my eyes',
'BAE':'Before anyone else',
'FIMH':'Forever in my heart',
'BSAAW':'Big smile and a wink',
'BWL':'Bursting with laughter',
'LMAO':'Laughing my ass off',
'BFF': 'Best friends forever',
'CSL':"Can't stop laughing"}

# %%
def chat_conversion(text):
  new_text = []
  for w in text.split():
    if w.upper() in chat_words:
      new_text.append(chat_words[w.upper()].lower())
    else:
      new_text.append(w)
  return " ".join(new_text)

# %%
text = "i need that thing asap"
print(chat_conversion(text))
text = "i bored : hope your wlan will go today!"
print(chat_conversion(text))
# Out:
# i need that thing as soon as possible
# i bored : hope your wlan will go today!

# %%
x_train['comment'] = x_train['comment'].apply(chat_conversion)
x_test['comment'] = x_test['comment'].apply(chat_conversion)

# %%
x_train
# Out:
#                                                  comment
# 15707  exhausting day. and more to come tomorrow! cit...
# 21368                 got six feet under series 1 on dvd
# 392    just discovered a shortcoming of gravity. when...
# 23187  i was so hype about it being friday & it raini...
# 19983  trying to draw some manga/anime for our new we...
# ...                                                  ...
# 24832  my class will be at chem sc building. will see...
# 2935            the sun is shining and i'm stuck in work
# 26768          i'm bored : hope your wlan will go today!
# 6619   just wanted to point out that on youtube, you ...
# 24895      havin fun? x by the way isnt it bowling? ****
#
# [21984 rows x 1 columns]

# %% [markdown]
# ### Stop words removal

# %%
import nltk

# %%
# download once
# nltk.download('stopwords')
# nltk.download('punkt')

# %%
from nltk.corpus import stopwords

# %%
st = stopwords.words('english')
st.extend(["i'm"])

# %%
sorted(st, key=str.lower)
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'm",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves']

# %%
def remove_stopwords(text):
  new_text = []

  for word in text.split():
    if word in st:
      new_text.append('')
    else:
      new_text.append(word)
  x = new_text[:]
  new_text.clear()
  return " ".join(x)

# %%
remove_stopwords("Man, don't  that wine looks so nice. The red wines Clovis always brings out isn&#39;t like the normal red wine color. It always looks like a fruit punch strawberry lemonade color and looks so delicious.")
# Out:
# 'Man,   wine looks  nice. The red wines Clovis always brings  isn&#39;t like  normal red wine color. It always looks like  fruit punch strawberry lemonade color  looks  delicious.'

# %%
x_train['comment'][26768]
# Out:
# "i'm bored : hope your wlan will go today!"

# %%
x_train['comment'].apply(remove_stopwords)
# Out:
# 15707    exhausting day.    come tomorrow! city  mother...
# 21368                          got six feet  series 1  dvd
# 392       discovered  shortcoming  gravity.   use twitp...
# 23187       hype    friday &  raining outside..no rain ...
# 19983    trying  draw  manga/anime   new website ...  b...
#                                ...
# 24832         class    chem sc building.  see      5 yeah?
# 2935                            sun  shining   stuck  work
# 26768                        bored : hope  wlan  go today!
# 6619      wanted  point    youtube,    subscribers  tom...
# 24895               havin fun? x   way isnt  bowling? ****
# Name: comment, Length: 21984, dtype: object

# %%
x_train['comment'] = x_train['comment'].apply(remove_stopwords)
x_test['comment'] = x_test['comment'].apply(remove_stopwords)

# %% [markdown]
# ### Remove Punctuation
# It should be called after all preprocessing

# %%
import string

# %%
exclude = string.punctuation
exclude
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punc(text):
  return text.translate(str.maketrans('','',exclude))

# %%
print(remove_punc("cdsdcsd'sdsd?-bbn.>()"))
# Out:
# cdsdcsdsdsdbbn

# %%
x_train['comment'].apply(remove_punc)
# Out:
# 15707    exhausting day    come tomorrow city  mothers ...
# 21368                          got six feet  series 1  dvd
# 392       discovered  shortcoming  gravity   use twitpi...
# 23187       hype    friday   raining outsideno rain  da...
# 19983    trying  draw  mangaanime   new website   bad idea
#                                ...
# 24832           class    chem sc building  see      5 yeah
# 2935                            sun  shining   stuck  work
# 26768                          bored  hope  wlan  go today
# 6619      wanted  point    youtube    subscribers  tom ...
# 24895                     havin fun x   way isnt  bowling
# Name: comment, Length: 21984, dtype: object

# %%
x_train['comment'] = x_train['comment'].apply(remove_punc)
x_test['comment'] = x_test['comment'].apply(remove_punc)

# %% [markdown]
# ### Handling emojis

# %%
# !pip install emoji

# %%
import emoji

# %%
print(emoji.demojize(df['comment'][249]))
print(emoji.demojize(df['comment'][370]))
# Out:
#  I live for pain, bring it on
#  u really don`t think so?  maybe ur right....lol. btw what phone u using? think u told me b4...i might have an app for u

# %%
emoji.demojize("sdgsadhfdhg 🔥")
# Out:
# 'sdgsadhfdhg :fire:'

# %%
df['comment'].apply(emoji.demojize)[249]
# Out:
# ' I live for pain, bring it on'

# %%
x_train['comment'] = x_train['comment'].apply(emoji.demojize)
x_test['comment'] = x_test['comment'].apply(emoji.demojize)

# %%
x_train['comment']
# Out:
# 15707    exhausting day    come tomorrow city  mothers ...
# 21368                          got six feet  series 1  dvd
# 392       discovered  shortcoming  gravity   use twitpi...
# 23187       hype    friday   raining outsideno rain  da...
# 19983    trying  draw  mangaanime   new website   bad idea
#                                ...
# 24832           class    chem sc building  see      5 yeah
# 2935                            sun  shining   stuck  work
# 26768                          bored  hope  wlan  go today
# 6619      wanted  point    youtube    subscribers  tom ...
# 24895                     havin fun x   way isnt  bowling
# Name: comment, Length: 21984, dtype: object

# %% [markdown]
# ### Stemming

# %%
from nltk.stem.porter import PorterStemmer

# %%
ps = PorterStemmer()
def stem_words(text):
  return " ".join([ps.stem(word) for word in text.split()])

# %%
text = "walk walked walking walks"
stem_words(text)
# Out:
# 'walk walk walk walk'

# %%
text = "act acts actor acting actress"
stem_words(text)
# Out:
# 'act act actor act actress'

# %%
text = "my boss is bullying me..."

# %%
# sometime word cannot be a valid word in the languag as well, if we want to that it must be valid word in language, then, we must use lemmatization(slow in running) which ensures that the word is a valid word
stem_words(text)
# Out:
# 'my boss is bulli me...'

# %%
x_train['comment'].apply(stem_words)
# Out:
# 15707    exhaust day come tomorrow citi mother day cant...
# 21368                              got six feet seri 1 dvd
# 392      discov shortcom graviti use twitpic integr sub...
# 23187    hype friday rain outsideno rain day rainin tea...
# 19983               tri draw mangaanim new websit bad idea
#                                ...
# 24832                       class chem sc build see 5 yeah
# 2935                                  sun shine stuck work
# 26768                              bore hope wlan go today
# 6619     want point youtub subscrib tom felton thought ...
# 24895                            havin fun x way isnt bowl
# Name: comment, Length: 21984, dtype: object

# %%
x_train['comment'] = x_train['comment'].apply(stem_words)
x_test['comment'] = x_test['comment'].apply(stem_words)

# %% [markdown]
# ### Tokenization

# %%
text1 = "Man, that wine looks so nice. The red wines Clovis always brings out isn&#39;t like the normal red wine color. It always looks like a fruit punch strawberry lemonade color and looks so delicious."
text2 = """Didn't catch it earlier but man at start of video said Punkey Brewster. Now that is some 80s shit, when I grew up. Felt good hearing that as I missed it in earlier viewings of this video
so this is great! one thing I am missing is why keep using just does not fit!!
I watched this whole series backwards lol"""
text3 = 'I have a PH.D in A.I.'

# %%
pip install -U spacy
# Out:
# Requirement already satisfied: spacy in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (3.8.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.0 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from spacy) (8.3.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from spacy) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from spacy) (2.32.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from spacy) (2.5.3)
# Requirement already satisfied: jinja2 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from spacy) (69.5.1)
# Requirement already satisfied: packaging>=20.0 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from spacy) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<1.1.0,>=1.0.0 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.0->spacy) (1.0.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.0->spacy) (0.1.5)
# Collecting numpy>=1.19.0 (from spacy)
#   Using cached numpy-2.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Requirement already satisfied: click>=8.0.0 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.3.5)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /home/prashant-maurya/anaconda3/lib/python3.12/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.0)
# Using cached numpy-2.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.2 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# WARNING: Skipping /home/prashant-maurya/anaconda3/lib/python3.12/site-packages/numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.59.1 requires numpy<1.27,>=1.22, but you have numpy 2.0.2 which is incompatible.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.0.2 which is incompatible.
# streamlit 1.32.0 requires numpy<2,>=1.19.3, but you have numpy 2.0.2 which is incompatible.
# pywavelets 1.5.0 requires numpy<2.0,>=1.22.4, but you have numpy 2.0.2 which is incompatible.
# Successfully installed numpy-2.0.2
# WARNING: Skipping /home/prashant-maurya/anaconda3/lib/python3.12/site-packages/numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/prashant-maurya/anaconda3/lib/python3.12/site-packages/numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/prashant-maurya/anaconda3/lib/python3.12/site-packages/numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[160], line 1
# ----> 1 import spacy
#
# File ~/anaconda3/lib/python3.12/site-packages/spacy/__init__.py:13
#      10 # These are imported as part of the API
#      11 from thinc.api import Config, prefer_gpu, require_cpu, require_gpu  # noqa: F401
# ---> 13 from . import pipeline  # noqa: F401
#      14 from . import util
#      15 from .about import __version__  # noqa: F401
#
# File ~/anaconda3/lib/python3.12/site-packages/spacy/pipeline/__init__.py:1
# ----> 1 from .attributeruler import AttributeRuler
#       2 from .dep_parser import DependencyParser
#       3 from .edit_tree_lemmatizer import EditTreeLemmatizer
#
# File ~/anaconda3/lib/python3.12/site-packages/spacy/pipeline/attributeruler.py:8
#       6 from .. import util
#       7 from ..errors import Errors
# ----> 8 from ..language import Language
#       9 from ..matcher import Matcher
#      10 from ..scorer import Scorer
#
# File ~/anaconda3/lib/python3.12/site-packages/spacy/language.py:46
#      44 from .lang.tokenizer_exceptions import BASE_EXCEPTIONS, URL_MATCH
#      45 from .lookups import load_lookups
# ---> 46 from .pipe_analysis import analyze_pipes, print_pipe_analysis, validate_attrs
#      47 from .schemas import (
#      48     ConfigSchema,
#      49     ConfigSchemaInit,
#    (...)
#      52     validate_init_settings,
#      53 )
#      54 from .scorer import Scorer
#
# File ~/anaconda3/lib/python3.12/site-packages/spacy/pipe_analysis.py:6
#       3 from wasabi import msg
#       5 from .errors import Errors
# ----> 6 from .tokens import Doc, Span, Token
#       7 from .util import dot_to_dict
#       9 if TYPE_CHECKING:
#      10     # This lets us add type hints for mypy etc. without causing circular imports
#
# File ~/anaconda3/lib/python3.12/site-packages/spacy/tokens/__init__.py:1
# ----> 1 from ._serialize import DocBin
#       2 from .doc import Doc
#       3 from .morphanalysis import MorphAnalysis
#
# File ~/anaconda3/lib/python3.12/site-packages/spacy/tokens/_serialize.py:14
#      12 from ..errors import Errors
#      13 from ..util import SimpleFrozenList, ensure_path
# ---> 14 from ..vocab import Vocab
#      15 from ._dict_proxies import SpanGroups
#      16 from .doc import DOCBIN_ALL_ATTRS as ALL_ATTRS
#
# File ~/anaconda3/lib/python3.12/site-packages/spacy/vocab.pyx:1, in init spacy.vocab()
#
# File ~/anaconda3/lib/python3.12/site-packages/spacy/tokens/doc.pyx:49, in init spacy.tokens.doc()
#
# File ~/anaconda3/lib/python3.12/site-packages/spacy/schemas.py:195
#     191         obj = converted
#     192     return validate(TokenPatternSchema, {"pattern": obj})
# --> 195 class TokenPatternString(BaseModel):
#     196     REGEX: Optional[Union[StrictStr, "TokenPatternString"]] = Field(None, alias="regex")
#     197     IN: Optional[List[StrictStr]] = Field(None, alias="in")
#
# File ~/anaconda3/lib/python3.12/site-packages/pydantic/v1/main.py:286, in ModelMetaclass.__new__(mcs, name, bases, namespace, **kwargs)
#     284 cls.__signature__ = ClassAttribute('__signature__', generate_model_signature(cls.__init__, fields, config))
#     285 if resolve_forward_refs:
# --> 286     cls.__try_update_forward_refs__()
#     288 # preserve `__set_name__` protocol defined in https://peps.python.org/pep-0487
#     289 # for attributes not in `new_namespace` (e.g. private attributes)
#     290 for name, obj in namespace.items():
#
# File ~/anaconda3/lib/python3.12/site-packages/pydantic/v1/main.py:808, in BaseModel.__try_update_forward_refs__(cls, **localns)
#     802 @classmethod
#     803 def __try_update_forward_refs__(cls, **localns: Any) -> None:
#     804     """
#     805     Same as update_forward_refs but will not raise exception
#     806     when forward references are not defined.
#     807     """
# --> 808     update_model_forward_refs(cls, cls.__fields__.values(), cls.__config__.json_encoders, localns, (NameError,))
#
# File ~/anaconda3/lib/python3.12/site-packages/pydantic/v1/typing.py:554, in update_model_forward_refs(model, fields, json_encoders, localns, exc_to_suppress)
#     552 for f in fields:
#     553     try:
# --> 554         update_field_forward_refs(f, globalns=globalns, localns=localns)
#     555     except exc_to_suppress:
#     556         pass
#
# File ~/anaconda3/lib/python3.12/site-packages/pydantic/v1/typing.py:529, in update_field_forward_refs(field, globalns, localns)
#     527 if field.sub_fields:
#     528     for sub_f in field.sub_fields:
# --> 529         update_field_forward_refs(sub_f, globalns=globalns, localns=localns)
#     531 if field.discriminator_key is not None:
#     532     field.prepare_discriminated_union_sub_fields()
#
# File ~/anaconda3/lib/python3.12/site-packages/pydantic/v1/typing.py:520, in update_field_forward_refs(field, globalns, localns)
#     518 if field.type_.__class__ == ForwardRef:
#     519     prepare = True
# --> 520     field.type_ = evaluate_forwardref(field.type_, globalns, localns or None)
#     521 if field.outer_type_.__class__ == ForwardRef:
#     522     prepare = True
#
# File ~/anaconda3/lib/python3.12/site-packages/pydantic/v1/typing.py:66, in evaluate_forwardref(type_, globalns, localns)
#      63 def evaluate_forwardref(type_: ForwardRef, globalns: Any, localns: Any) -> Any:
#      64     # Even though it is the right signature for python 3.9, mypy complains with
#      65     # `error: Too many arguments for "_evaluate" of "ForwardRef"` hence the cast...
# ---> 66     return cast(Any, type_)._evaluate(globalns, localns, set())
#
# TypeError: ForwardRef._evaluate() missing 1 required keyword-only argument: 'recursive_guard'

# %%
tokenise = spacy.load('en_core_web_sm')

# %%
doc1 = tokenise(text1)
doc2 = tokenise(text2)
doc3 = tokenise(text3)

# %%
for token in doc1:
  print(token)
# Out:
# Man
# ,
# that
# wine
# looks
# so
# nice
# .
# The
# red
# wines
# Clovis
# always
# brings
# out
# isn&#39;t
# like
# the
# normal
# red
# wine
# color
# .
# It
# always
# looks
# like
# a
# fruit
# punch
# strawberry
# lemonade
# color
# and
# looks
# so
# delicious
# .

# %%
for token in doc2:
  print(token)
# Out:
# Did
# n't
# catch
# it
# earlier
# but
# man
# at
# start
# of
# video
# said
# Punkey
# Brewster
# .
# Now
# that
# is
# some
# 80s
# shit
# ,
# when
# I
# grew
# up
# .
# Felt
# good
# hearing
# that
# as
# I
# missed
# it
# in
# earlier
# viewings
# of
# this
# video
#
#
# so
# this
# is
# great
# !
# one
# thing
# I
# am
# missing
# is
# why
# keep
# using
# just
# does
# not
# fit
# !
# !
#
#
# I
# watched
# this
# whole
# series
# backwards
# lol

# %%
for token in doc3:
  print(token)
# Out:
# I
# have
# a
# PH.D
# in
# A.I.

# %%
import gensim

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
corpus = []
def make_tokenised_2d_array(text):
  raw_sent = sent_tokenize(text)
  for sent in raw_sent:
    corpus.append(simple_preprocess(sent))

# %%
x_train['comment'].apply(make_tokenised_2d_array)
# Out:
# 15707    None
# 21368    None
# 392      None
# 23187    None
# 19983    None
#          ...
# 24832    None
# 2935     None
# 26768    None
# 6619     None
# 24895    None
# Name: comment, Length: 21984, dtype: object

# %%
corpus
# Out:
# [['exhaust',
#   'day',
#   'come',
#   'tomorrow',
#   'citi',
#   'mother',
#   'day',
#   'cant',
#   'wait',
#   'minu',
#   'drive'],
#  ['got', 'six', 'feet', 'seri', 'dvd'],
#  ['discov',
#   'shortcom',
#   'graviti',
#   'use',
#   'twitpic',
#   'integr',
#   'subtract',
#   'pic',
#   'url',
#   'charact',
#   'limit'],
#  ['hype',
#   'friday',
#   'rain',
#   'outsideno',
#   'rain',
#   'day',
#   'rainin',
#   'tear',
#   'eye',
#   'kickitmr',
#   'sun',
#   'trippin'],
#  ['tri', 'draw', 'mangaanim', 'new', 'websit', 'bad', 'idea'],
#  ['break',
#   'news',
#   'broiler',
#   'burger',
#   'king',
#   'down',
#   'burger',
#   'burger',
#   'king',
#   'lunch',
#   'least',
#   'chicken',
#   'fri',
#   'there'],
#  ['cuddl', 'girl', 'cuddl', 'fun', 'soft'],
#  ['roll',
#   'floor',
#   'laugh',
#   'even',
#   'kept',
#   'insur',
#   'payment',
#   'im',
#   'still',
#   'like',
#   'meh',
#   'good',
#   'thing',
#   'appli',
#   'day',
#   'job',
#   'pasi',
#   'mo'],
#  ['hate', 'sick', 'miss'],
#  ['much', 'skype', 'blackberri', 'may'],
#  ['struggl', 'todaynola', 'woke', 'run', 'sleep'],
#  ['sorri', 'bout', 'cat'],
#  ['ruth', 'today'],
#  ['no',
#   'noth',
#   'import',
#   'like',
#   'look',
#   'like',
#   'that',
#   'old',
#   'hairstyp',
#   'actual'],
#  ['tri',
#   'go',
#   'can',
#   'tell',
#   'everyon',
#   'goe',
#   'montreal',
#   'check',
#   'out',
#   'even',
#   'peopl',
#   'live'],
#  ['that',
#   'birthday',
#   'boy',
#   'ipod',
#   'touch',
#   'dsi',
#   'setup',
#   'sort',
#   'think',
#   'would',
#   'happi',
#   'ball',
#   'boot',
#   'age'],
#  ['back',
#   'home',
#   'moment',
#   'iã',
#   'â½m',
#   'speak',
#   'aunt',
#   'telephon',
#   'dariu',
#   'neight',
#   'backround',
#   'miss',
#   'littl',
#   'hors'],
#  ['mostli',
#   'go',
#   'work',
#   'updat',
#   'twilight',
#   'blog',
#   'basic',
#   'that',
#   'life',
#   'sleeptim',
#   'you'],
#  ['listen', 'fountain', 'youth', 'supastit', 'ive', 'feel', 'music', 'day'],
#  ['need', 'peopl', 'talk', 'pleas', 'im', 'bore', 'follow', 'me'],
#  ['stun', 'busi', 'card', 'asham', 'mine'],
#  ['hmm', 'anyon', 'els', 'iphon', 'earphon', 'grey', 'rubber', 'disintegr'],
#  ['im', 'get', 'treatment', 'gonna', 'hang', 'pool', 'hot', 'tub'],
#  ['thank', 'you'],
#  ['workin', 'la', 'bootay', 'where', 'warm', 'weather', 'at'],
#  ['ryan',
#   'stile',
#   'still',
#   'funniest',
#   'man',
#   'ever',
#   'got',
#   'great',
#   'news',
#   'great',
#   'news',
#   'tonight',
#   'happi',
#   'could',
#   'burst'],
#  ['great',
#   'meet',
#   'you',
#   'thank',
#   'use',
#   'umbrellai',
#   'hope',
#   'ate',
#   'got',
#   'sleep'],
#  ['look', 'like', 'fun'],
#  ['one', 'fake', 'you', 'follow', 'me', 'haha', 'wish', 'would', 'instead'],
#  ['watchin', 'hannah', 'montana', 'hoedown', 'throwdown'],
#  ['short', 'usual', 'awesom'],
#  ['awoooogahhhhhh',
#   'hehee',
#   'hope',
#   'get',
#   'decent',
#   'price',
#   'breakfast',
#   'real',
#   'quick',
#   'david'],
#  ['driven',
#   'theatr',
#   'develop',
#   'thick',
#   'skin',
#   'yo',
#   'audit',
#   'sinc',
#   'gotten',
#   'part'],
#  ['wait',
#   'listen',
#   'wind',
#   'blow',
#   'tumblewe',
#   'none',
#   'old',
#   'enough',
#   'know',
#   'someon',
#   'say',
#   'crackerack'],
#  ['let', 'get', 'rich', 'give', 'everyon', 'nice', 'sweater', 'teach', 'danc'],
#  ['welcom', 'twitter', 'realli', 'cool', 'here', 'greet', 'viennaaustria'],
#  ['hairdy', 'patch', 'test', 'smear', 'white', 'duvet', 'cover'],
#  ['dive',
#   'ocean',
#   'deep',
#   'dive',
#   'vi',
#   'sun',
#   'colour',
#   'dynamit',
#   'fish',
#   'done',
#   'toll',
#   'reef'],
#  ['notic', 'hallway', 'worri', 'bbqim', 'hope', 'come'],
#  ['thank',
#   'accept',
#   'request',
#   'must',
#   'take',
#   'care',
#   'littl',
#   'girl',
#   'mayb',
#   'write',
#   'back',
#   'later'],
#  ['morn', 'workout', 'sesh', 'love', 'life'],
#  ['shudder', 'thought', 'think', 'shed', 'shed', 'manag', 'reclaim', 'it'],
#  ['ummm', 'idk', 'courtney', 'date', 'hook', 'us', 'up'],
#  ['ok', 'cant', 'sleep', 'twitter'],
#  ['woke', 'earli', 'still', 'sick'],
#  ['aww', 'cant', 'wait', 'back', 'la'],
#  ['ipod',
#   'taken',
#   'last',
#   'breath',
#   'im',
#   'truli',
#   'devast',
#   'lost',
#   'public',
#   'transport',
#   'companion'],
#  ['uni', 'assign'],
#  ['like', 'them', 'mean', 'like', 'what', 'left', 'them'],
#  ['realli', 'want', 'go', 'see', 'script', 'ny', 'august', 'one', 'go'],
#  ['wait', 'lie'],
#  ['sign', 'tart', 'news', 'intro', 'newslett', 'first', 'purchas', 'for'],
#  ['today', 'lonley', 'girl', 'guitar'],
#  ['think', 'ill', 'home', 'want', 'next', 'week', 'work', 'book', 'forseeabl'],
#  ['appreci', 'kind', 'word', 'glad', 'word', 'reson'],
#  ['gotta', 'assign', 'tomorrow', 'omg', 'mackillop', 'swine'],
#  ['fell', 'deep', 'crack', 'glacier', 'terribl'],
#  ['tear', 'eye', 'like', 'reservesi', 'lost', 'one'],
#  ['nice', 'dinner', 'hubbi', 'way', 'home', 'min', 'drive', 'citi', 'sigh'],
#  ['get', 'job', 'keep', 'appli', 'schooli', 'want', 'teach'],
#  ['eat', 'pancak', 'better', 'day', 'steviej'],
#  ['final',
#   'home',
#   'tp',
#   'tetep',
#   'kurang',
#   'bt',
#   'buat',
#   'shoot',
#   'kami',
#   'nih',
#   'huaaaa',
#   'stress',
#   'gila',
#   'syapa',
#   'lg',
#   'ya'],
#  ['went',
#   'find',
#   'uniti',
#   'girl',
#   'bebo',
#   'cant',
#   'find',
#   'her',
#   'fail',
#   'bebo',
#   'stalk'],
#  ['excel', 'never', 'know', 'lmao'],
#  ['dam',
#   'finish',
#   'watch',
#   'prison',
#   'break',
#   'final',
#   'breakomg',
#   'dont',
#   'think',
#   'ive',
#   'cri',
#   'hard',
#   'showfin',
#   'understand',
#   'final'],
#  ['listen', 'broken', 'lifehous', 'on', 'repeat'],
#  ['know', 'fall', 'right', 'pm', 'time', 'like', 'right', 'middl', 'day'],
#  ['sent', 'direct', 'messag', 'there', 'mail'],
#  ['express', 'didnt', 'get', 'see', 'tonight'],
#  ['geniu',
#   'put',
#   'rug',
#   'wash',
#   'machin',
#   'left',
#   'fold',
#   'door',
#   'half',
#   'open',
#   'machin',
#   'move',
#   'door',
#   'close',
#   'open',
#   'shake',
#   'head'],
#  ['sorri',
#   'get',
#   'projector',
#   'work',
#   'windoz',
#   'laptop',
#   'ton',
#   'peopl',
#   'came',
#   'afterward',
#   'saw',
#   'live'],
#  ['monstr', 'may', 'tri', 'prism'],
#  ['mani', 'mani', 'thank', 'it', 'school', 'weeeee'],
#  ['happi', 'mother', 'day', 'mark'],
#  ['thank', 'review', 'today', 'feel', 'like', 'idk', 'anyth', 'anyway'],
#  ['need', 'hug', 'anymor'],
#  ['flippin', 'sweet', 'dude', 'thank', 'share'],
#  ['find', 'dress'],
#  ['sorri',
#   'respons',
#   'assist',
#   'job',
#   'alreadi',
#   'fill',
#   'pleas',
#   'check',
#   'back',
#   'soon',
#   'sure',
#   'last',
#   'long'],
#  ['come', 'bulgaria', 'great', 'fan', 'here'],
#  ['bah', 'think', 'fb', 'fan', 'page', 'get'],
#  ['shower', 'feel', 'refresh', 'long', 'day', 'fair'],
#  ['ooooh',
#   'jealou',
#   'might',
#   'tri',
#   'get',
#   'saturday',
#   'exam',
#   'monday',
#   'im',
#   'gonna',
#   'fail'],
#  ['order', 'pizza', 'watch', 'diggnat', 'tri', 'tweetdeck', 'good'],
#  ['head', 'vanciti', 'ive', 'heard', 'hwi', 'close', 'east', 'bound', 'cwack'],
#  ['want', 'go', 'see'],
#  ['call', 'win'],
#  ['absolut', 'love', 'mike', 'watt', 'sexi', 'hero'],
#  ['like', 'last', 'part', 'methodolog'],
#  ['watch',
#   'good',
#   'famili',
#   'premier',
#   'onlin',
#   'think',
#   'may',
#   'last',
#   'episod',
#   'watch',
#   'pretti',
#   'amazingli',
#   'mediocr',
#   'pass'],
#  ['educ',
#   'thank',
#   'photo',
#   'look',
#   'great',
#   'ill',
#   'comment',
#   'soon',
#   'possibl'],
#  ['great', 'song', 'cobra', 'starship', 'feat', 'leighton', 'meester'],
#  ['label', 'sorri', 'know', 'realli', 'needi'],
#  ['cup', 'cake', 'sooo', 'yummi', 'would', 'coffe', 'chaser', 'know', 'lead'],
#  ['nvm', 'lexi', 'playlist', 'work', 'magic'],
#  ['hope', 'nice', 'sleep'],
#  ['im', 'sosososo', 'sad', 'see', 'cori', 'lamb', 'hour', 'love', 'kid'],
#  ['get',
#   'readi',
#   'graduat',
#   'parti',
#   'id',
#   'much',
#   'rather',
#   'hello',
#   'marque',
#   'dane',
#   'cook'],
#  ['chees', 'chip'],
#  ['feel',
#   'great',
#   'solv',
#   'minor',
#   'long',
#   'term',
#   'problem',
#   'max',
#   'now',
#   'mayb',
#   'tri',
#   'anim',
#   'avatar',
#   'all',
#   'xd'],
#  ['know', 'say', 'itim', 'hell'],
#  ['scrub', 'tonight', 'pm', 'woo'],
#  ['daddi', 'leftwithout'],
#  ['tonight', 'hilariouss', 'loveee', 'everyon', 'there'],
#  ['enjoy',
#   'day',
#   'too',
#   'prob',
#   'see',
#   'top',
#   'glyder',
#   'pint',
#   'me',
#   'gotta',
#   'drive',
#   'straight',
#   'back',
#   'weve',
#   'got',
#   'dog',
#   'stuff',
#   'sunday'],
#  ['bed',
#   'finger',
#   'toe',
#   'everyth',
#   'cross',
#   'pick',
#   'melol',
#   'hope',
#   'ur',
#   'well',
#   'got',
#   'back',
#   'safepoor',
#   'jon'],
#  ['figur',
#   'strong',
#   'guy',
#   'suppos',
#   'put',
#   'heavi',
#   'thing',
#   'top',
#   'shelv',
#   'ouch'],
#  ['fault',
#   'leav',
#   'flipflop',
#   'outsid',
#   'locker',
#   'swim',
#   'usf',
#   'koret',
#   'oh',
#   'would',
#   'want',
#   'take',
#   'em',
#   'imt'],
#  ['play', 'zeke', 'he', 'leav', 'today'],
#  ['sound', 'good', 'thi', 'patch', 'brought'],
#  ['ask', 'time'],
#  ['riot'],
#  ['bad', 'newss'],
#  ['babsi',
#   'there',
#   'manual',
#   'process',
#   'take',
#   'ever',
#   'outlook',
#   'databas',
#   'pffff',
#   'crappi',
#   'msft',
#   'product'],
#  ['th', 'wed', 'anniversari', 'today', 'lucki', 'gorgeou', 'wife'],
#  ['so',
#   'yarn',
#   'arriv',
#   'monday',
#   'even',
#   'know',
#   'what',
#   'shipment',
#   'noth',
#   'dye',
#   'what'],
#  ['hiiiiii', 'text', 'day', 'respond', 'what', 'that'],
#  ['ohhh', 'someon', 'like', 'play', 'food', 'heehe'],
#  ['saddest', 'celeb', 'stori', 'week'],
#  ['mailbox', 'alreadi', 'hour'],
#  ['fridayand', 'sun', 'outbut', 'work', 'insid'],
#  ['one', 'final', 'down', 'two', 'go'],
#  ['smh',
#   'ppl',
#   'twit',
#   'friday',
#   'bc',
#   'got',
#   'follow',
#   'theyr',
#   'still',
#   'bank',
#   'nofakeri'],
#  ['good'],
#  ['go', 'miss', 'miss', 'suhana'],
#  ['home', 'marco', 'island', 'miss', 'girl', 'alreadyback', 'work'],
#  ['road', 'bet', 'would', 'right', 'mmot'],
#  ['oh', 'lord', 'idea', 'spout', 'get', 'anyon'],
#  ['one', 'saddest', 'song', 'ive', 'ever', 'heard'],
#  ['inthemak', 'aw'],
#  ['min',
#   'hr',
#   'min',
#   'googl',
#   'wave',
#   'demo',
#   'look',
#   'lot',
#   'fun',
#   'would',
#   'love',
#   'test',
#   'though'],
#  ['work', 'til'],
#  ['noth',
#   'definit',
#   'yetand',
#   'show',
#   'week',
#   'may',
#   'resort',
#   'give',
#   'away'],
#  ['hey', 'song', 'that', 'would', 'like', 'listen'],
#  ['nah', 'understand', 'cant', 'cancel', 'want', 'come'],
#  ['if',
#   'see',
#   'christoph',
#   'pleas',
#   'tell',
#   'lunch',
#   'pack',
#   'morn',
#   'left',
#   'fridg'],
#  ['earlier', 'stupid', 'orthadontist', 'appoint'],
#  ['confus',
#   'peopl',
#   'pose',
#   'other',
#   'twitter',
#   'mean',
#   'realli',
#   'homework',
#   'peopl',
#   'live',
#   'imit',
#   'them',
#   'sad'],
#  ['realli',
#   'wanna',
#   'see',
#   'jona',
#   'brother',
#   'novemeb',
#   'need',
#   'find',
#   'someon',
#   'come',
#   'me'],
#  ['mode', 'home', 'offic'],
#  ['make', 'sure', 'come', 'back', 'comment', 'again'],
#  ['noooo',
#   'littl',
#   'piggi',
#   'ill',
#   'vote',
#   'anyway',
#   'hmpf',
#   'need',
#   'hang',
#   'soon',
#   'pl',
#   'hug'],
#  ['sick', 'wife', 'bday', 'doubl'],
#  ['alway',
#   'good',
#   'day',
#   'make',
#   'good',
#   'tear',
#   'eye',
#   'make',
#   'better',
#   'ur',
#   'morn',
#   'greet',
#   'thank',
#   'you'],
#  ['wow', 'realli', 'need', 'fun', 'tonight'],
#  ['brodi', 'dare'],
#  ['could',
#   'bare',
#   'speak',
#   'probabl',
#   'think',
#   'who',
#   'weirdo',
#   'looool',
#   'say',
#   'sorri',
#   'pleas'],
#  ['end',
#   'face',
#   'face',
#   'bear',
#   'drive',
#   'home',
#   'even',
#   'sadli',
#   'took',
#   'wood',
#   'haul',
#   'cameraphon'],
#  ['morn',
#   'dude',
#   'ivi',
#   'decid',
#   'want',
#   'go',
#   'boat',
#   'today',
#   'guy',
#   'around',
#   'pm',
#   'would',
#   'nice',
#   'see',
#   'you'],
#  ['oopstoo',
#   'late',
#   'alreadi',
#   'pop',
#   'bridg',
#   'sinc',
#   'miss',
#   'tv',
#   'blair',
#   'jo',
#   'too'],
#  ['well',
#   'greatli',
#   'appreci',
#   'comment',
#   'mean',
#   'lot',
#   'me',
#   'work',
#   'themwork',
#   'progress',
#   'know'],
#  ['home', 'work', 'hour', 'sleep', 'put', 'mile', 'new', 'bike'],
#  ['omg', 'luv', 'guy', 'thank', 'keepin', 'entertain', 'awak'],
#  ['havin',
#   'bad',
#   'weed',
#   'first',
#   'wisdom',
#   'teeth',
#   'ran',
#   'weed',
#   'might',
#   'get',
#   'sick',
#   'weed'],
#  ['thank', 'tri'],
#  ['think', 'like', 'workshop'],
#  ['tri', 'save', 'money', 'ipod', 'touch'],
#  ['get', 'readi', 'dayyyyyyyyyyyi', 'hope', 'work', 'goe', 'good'],
#  ['would',
#   'panic',
#   'littl',
#   'mayb',
#   'read',
#   'orbitron',
#   'gym',
#   'like',
#   'dowhen',
#   'els',
#   'fail'],
#  ['sleep', 'bed', 'tonight', 'home'],
#  ['rain', 'bring', 'back', 'memori'],
#  ['morn',
#   'warner',
#   'soon',
#   'lot',
#   'do',
#   'go',
#   'school',
#   'work',
#   'hope',
#   'everyon',
#   'great',
#   'day'],
#  ['medal', 'drivin', 'home', 'hour'],
#  ['glad', 'fine', 'thank', 'anoth', 'night', 'full'],
#  ['cut', 'thumb', 'broken', 'coffe', 'pot'],
#  ['research', 'nyc', 'stuff'],
#  ['thing', 'parent', 'best', 'friend'],
#  ['least', 'get', 'watch', 'tear', 'eye', 'let', 'go', 'pen'],
#  ['hour', 'sleep', 'tear', 'eye', 'bed', 'alaskaso', 'far', 'good'],
#  ['one', 'favorit', 'relax', 'song', 'wake', 'to', 'good', 'morn'],
#  ['seem', 'disappear', 'life'],
#  ['ppl', 'dont', 'miss', 'follow', 'superstar', 'sunday'],
#  ['good', 'busi', 'heck', 'good', 'feel', 'yucki', 'moment'],
#  ['see', 'jona', 'brother', 'movi', 'funni', 'one', 'els', 'hahah', 'cant'],
#  ['hate', 'wait', 'line'],
#  ['big', 'shout', 'home', 'girl', 'know'],
#  ['trust', 'me', 'that', 'good', 'thing', 'someth', 'self', 'thank', 'you'],
#  ['got',
#   'back',
#   'arizona',
#   'yesterday',
#   'move',
#   'furnitur',
#   'stuff',
#   'arizona',
#   'hous',
#   'ship',
#   'redwood',
#   'citi',
#   'sad'],
#  ['lol',
#   'wen',
#   'mum',
#   'use',
#   'take',
#   'kid',
#   'wud',
#   'alway',
#   'eat',
#   'bread',
#   'instead',
#   'haha'],
#  ['mari',
#   'better',
#   'hudgen',
#   'omg',
#   'song',
#   'came',
#   'shuffl',
#   'would',
#   'citi',
#   'high'],
#  ['want', 'someon', 'come', 'take', 'pictur', 'one'],
#  ['still', 'stupidli', 'sickcancel', 'philli', 'trip', 'sad', 'day'],
#  ['dont', 'get', 'one', 'fine', 'say', 'text', 'way', 'meaning', 'twitter'],
#  ['anywayss', 'point', 'die', 'spend', 'summer', 'somewher', 'hot', 'guy'],
#  ['mourn', 'venu', 'third', 'round', 'loss'],
#  ['thank',
#   'god',
#   'elton',
#   'allow',
#   'see',
#   'new',
#   'tw',
#   'trailer',
#   'sinc',
#   'work',
#   'block',
#   'youtub',
#   'lj'],
#  ['excit', 'blow', 'anoth', 'candl', 'today', 'as', 'kid'],
#  ['vote', 'want', 'see', 'gino', 'drag', 'pleas', 'post', 'pictur'],
#  ['ive',
#   'sore',
#   'throat',
#   'sinc',
#   'monday',
#   'morn',
#   'im',
#   'sick',
#   'hurtin',
#   'want',
#   'freakin',
#   'sleep'],
#  ['may',
#   'st',
#   'success',
#   'luca',
#   'first',
#   'polic',
#   'contact',
#   'neighborhood',
#   'cruis',
#   'egg',
#   'cream',
#   'bumf',
#   'shave',
#   'foam',
#   'love',
#   'son',
#   'he',
#   'hero'],
#  ['pretti', 'ladi', 'happi', 'mother', 'day', 'mother', 'futur', 'soninlaw'],
#  ['stupid',
#   'competit',
#   'stuff',
#   'keep',
#   'get',
#   'way',
#   'go',
#   'get',
#   'word',
#   'today',
#   'kill',
#   'write'],
#  ['nd', 'period', 'studyhal', 'rememb', 'ipod', 'music', 'time'],
#  ['thank',
#   'approv',
#   'applic',
#   'twa',
#   'forum',
#   'honey',
#   'keep',
#   'good',
#   'work'],
#  ['long', 'day', 'much', 'fun', 'though', 'tomorrow', 'much'],
#  ['haha', 'philippin', 'want', 'follow', 'you'],
#  ['nooooo', 'get', 'now', 'haha', 'ill', 'gone', 'later'],
#  ['balmain',
#   'knockoff',
#   'bebe',
#   'make',
#   'sadi',
#   'want',
#   'real',
#   'dealthes',
#   'shoe',
#   'look',
#   'cheapi',
#   'cheapi'],
#  ['ah',
#   'nfg',
#   'super',
#   'amaz',
#   'jordan',
#   'pretti',
#   'legit',
#   'cant',
#   'stay',
#   'longer',
#   'meet',
#   'everyon',
#   'cuz',
#   'hv',
#   'hour',
#   'drive',
#   'home'],
#  ['might',
#   'guess',
#   'crafti',
#   'ladi',
#   'like',
#   'would',
#   'lamin',
#   'mine',
#   'cheap',
#   'one',
#   'work',
#   'brilliantli'],
#  ['dang', 'phone', 'still', 'broken', 'come', 'whenev'],
#  ['earli', 'morn', 'probabl', 'even', 'need', 'much', 'makeup'],
#  ['nomatt', 'much', 'sleep', 'still', 'tire'],
#  ['think',
#   'tamera',
#   'show',
#   'anywayth',
#   'cw',
#   'abc',
#   'fam',
#   'appreci',
#   'like',
#   'should'],
#  ['week',
#   'stay',
#   'grandmoth',
#   'home',
#   'lopatcong',
#   'start',
#   'new',
#   'book',
#   'tonight'],
#  ['revamp',
#   'record',
#   'studio',
#   'today',
#   'ad',
#   'nice',
#   'high',
#   'end',
#   'outboard',
#   'gearveri',
#   'exit'],
#  ['home', 'jack', 'now', 'cant', 'say', 'happi', 'either'],
#  ['ye', 'minut', 'sim', 'plu', 'season', 'fun', 'fun', 'expans'],
#  ['funni',
#   'right',
#   'like',
#   'bsb',
#   'im',
#   'fan',
#   'love',
#   'much',
#   'better',
#   'tupac',
#   'tlc',
#   'bad',
#   'theyr',
#   'sing',
#   'anymor'],
#  ['coupl',
#   'od',
#   'day',
#   'time',
#   'need',
#   'get',
#   'sleep',
#   'night',
#   'night',
#   'all',
#   'peac'],
#  ['ask', 'thnx', 'grite', 'take', 'care', 'god', 'bless'],
#  ['woe',
#   'definit',
#   'fun',
#   'travel',
#   'first',
#   'class',
#   'bike',
#   'fight',
#   'way',
#   'coach',
#   'til',
#   'reach',
#   'seat'],
#  ['get', 'assign', 'done'],
#  ['sit', 'school', 'suck', 'me'],
#  ['hope', 'happi', 'mother', 'day'],
#  ['even',
#   'spf',
#   'besid',
#   'need',
#   'put',
#   'chemic',
#   'face',
#   'spf',
#   'full',
#   'block'],
#  ['almost', 'legal', 'limit', 'db', 'garag'],
#  ['soooooooo', 'hungri', 'right', 'now', 'dh', 'still', 'home'],
#  ['meh', 'tri', 'one', 'commerci', 'drive', 'cat'],
#  ['good',
#   'question',
#   'nepal',
#   'pm',
#   'declar',
#   'resign',
#   'actual',
#   'resign',
#   'two',
#   'differ',
#   'thing'],
#  ['look',
#   'old',
#   'myspac',
#   'statu',
#   'oh',
#   'mann',
#   'skyrocket',
#   'flight',
#   'afternoon',
#   'delight',
#   'delight'],
#  ['relax', 'bed', 'go', 'sleep', 'nice', 'get', 'hous', 'tonight'],
#  ['well', 'wellso', 'sorri', 'let', 'danc', 'fabul', 'hobbi'],
#  ['excit', 'see', 'girl', 'today', 'bore', 'work', 'without'],
#  ['watch',
#   'wish',
#   'tv',
#   'month',
#   'love',
#   'guess',
#   'win',
#   'though',
#   'laugh',
#   'loud'],
#  ['rtwestcoastgal', 'facial', 'hair', 'need', 'shave', 'jr', 'jj'],
#  ['sleep', 'paperwork', 'do'],
#  ['ran', 'facebook', 'quizz', 'laugh', 'loud', 'groceri', 'shop', 'work'],
#  ['nothin'],
#  ['love',
#   'thank',
#   'much',
#   'say',
#   'hi',
#   'jenn',
#   'laura',
#   'yesterday',
#   'arcadia',
#   'friend',
#   'shannon',
#   'surpris',
#   'wthe',
#   'vid'],
#  ['morn', 'im', 'readi', 'weeee', 'sunday'],
#  ['sanctuarysunday',
#   'mission',
#   'make',
#   'sanctuari',
#   'trend',
#   'topic',
#   'day',
#   'lot',
#   'peopl',
#   'board',
#   'itjoin'],
#  ['tri', 'go', 'sleep', 'luck', 'think', 'sick'],
#  ['got', 'case', 'bubbl'],
#  ['friday',
#   'sun',
#   'shine',
#   'quit',
#   'warm',
#   'alreadi',
#   'walk',
#   'dog',
#   'freaki',
#   'hyper'],
#  ['ss',
#   'back',
#   'gym',
#   'project',
#   'final',
#   'finish',
#   'filthi',
#   'hobo',
#   'alway',
#   'tri',
#   'eat',
#   'taco'],
#  ['meeeee', 'sound', 'delici'],
#  ['fun', 'facebook'],
#  ['love',
#   'babi',
#   'hurt',
#   'me',
#   'hurt',
#   'me',
#   'more',
#   'want',
#   'watch',
#   'night',
#   'ruxburi',
#   'right',
#   'now'],
#  ['shower', 'pm', 'tripl', 'turn'],
#  ['go', 'winchest', 'sister', 'doesnt', 'go', 'more', 'bad', 'time'],
#  ['well',
#   'least',
#   'bad',
#   'thought',
#   'found',
#   'new',
#   'websit',
#   'watch',
#   'movi',
#   'gotta',
#   'sayit',
#   'bad',
#   'bad'],
#  ['sorri',
#   'again',
#   'twitter',
#   'ap',
#   'phone',
#   'text',
#   'it',
#   'repli',
#   'internet',
#   'now'],
#  ['ye',
#   'laugh',
#   'loud',
#   'that',
#   'good',
#   'one',
#   'remeb',
#   'bottom',
#   'alway',
#   'top'],
#  ['realiz',
#   'last',
#   'night',
#   'idea',
#   'pn',
#   'went',
#   'move',
#   'hope',
#   'lost',
#   'gone',
#   'forev'],
#  ['gonna', 'great', 'week', 'dalla', 'next', 'weekend'],
#  ['stomach', 'explod', 'wendi', 'everyth', 'tast', 'good', 'bad', 'you'],
#  ['one', 'get', 'marri'],
#  ['sad',
#   'id',
#   'love',
#   'talk',
#   'live',
#   'uk',
#   'cant',
#   'wait',
#   'new',
#   'album',
#   'pleas',
#   'say',
#   'hi'],
#  ['shall', 'drink', 'lot'],
#  ['okay', 'work', 'pleas', 'remind'],
#  ['gonna', 'come', 'show', 'minnesota', 'love', 'though', 'hun'],
#  ['want', 'comput'],
#  ['alreadi', 'know', 'happen', 'supernatur'],
#  ['yay', 'power', 'on', 'phone', 'charg', 'hot'],
#  ['realnash', 'want', 'honorari', 'filipino', 'ill', 'follow', 'thank'],
#  ['pheasant', 'dream', 'kaotic', 'one'],
#  ['feel',
#   'pain',
#   'man',
#   'peopl',
#   'say',
#   'realli',
#   'good',
#   'money',
#   'wast',
#   'ps'],
#  ['never', 'answer', 'back'],
#  ['sound', 'interest', 'wish', 'phone', 'java'],
#  ['start',
#   'tm',
#   'alex',
#   'whole',
#   'week',
#   'go',
#   'spend',
#   'money',
#   'dont',
#   'have'],
#  ['hahaha', 'bob', 'marley', 'one'],
#  ['hahaha',
#   'boyfriend',
#   'yeah',
#   'look',
#   'differ',
#   'there',
#   'he',
#   'cute',
#   'want',
#   'watch',
#   'movi'],
#  ['wanna', 'drink', 'pub'],
#  ['clean', 'clean', 'clean', 'today', 'work', 'out', 'love', 'work'],
#  ['hope', 'rain', 'sooo', 'warm'],
#  ['good', 'morningmidday', 'nation', 'formula', 'one', 'one', 'hour'],
#  ['love', 'song', 'lol', 'amaz', 'steph', 'xoxo'],
#  ['favorit',
#   'song',
#   'im',
#   'stand',
#   'dont',
#   'see',
#   'me',
#   'id',
#   'give',
#   'chang',
#   'dont',
#   'know',
#   'call'],
#  ['find', 'today', 'first', 'kiss'],
#  ['squar', 'sad', 'she', 'well', 'squar', 'crochet', 'bee', 'poli', 'fibe'],
#  ['anybodi', 'want', 'throw', 'basebal', 'around', 'me'],
#  ['god',
#   'earli',
#   'hayley',
#   'still',
#   'asleep',
#   'today',
#   'parti',
#   'day',
#   'get',
#   'stuff',
#   'readi'],
#  ['realli', 'like', 'pink', 'saw', 'live', 'new', 'tmobil', 'advert'],
#  ['wahamerican', 'chocol', 'chees', 'cake', 'chweet', 'mummi', 'muaxxx'],
#  ['man',
#   'look',
#   'pack',
#   'book',
#   'look',
#   'past',
#   'live',
#   'feel',
#   'kind',
#   'sentiment'],
#  ['tafe', 'actual', 'quit', 'good'],
#  ['steve', 'aoki', 'sorri', 'may', 'nxt', 'time'],
#  ['ed', 'cornwal', 'school', 'week', 'confus'],
#  ['yeah', 'know', 'feel', 'good', 'morn', 'mate'],
#  ['heh',
#   'seem',
#   'complex',
#   'iphon',
#   'jealousi',
#   'selfdeni',
#   'harm',
#   'let',
#   'out'],
#  ['headach'],
#  ['back', 'home', 'gonna', 'miss', 'everi', 'one'],
#  ['problem', 'photo', 'twitter', 'amfcant', 'see', 'face'],
#  ['simmon',
#   'everyon',
#   'mistak',
#   'make',
#   'lesson',
#   'learn',
#   'let',
#   'neg',
#   'get',
#   'you'],
#  ['got',
#   'back',
#   'carlton',
#   'greenvil',
#   'benz',
#   'get',
#   'servic',
#   'tear',
#   'eye',
#   'make',
#   'money',
#   'think',
#   'ill',
#   'make',
#   'sale',
#   'call'],
#  ['rip', 'fristi', 'think', 'abt'],
#  ['problem',
#   'adult',
#   'shirt',
#   'too',
#   'annoy',
#   'sinc',
#   'lot',
#   'adult',
#   'player',
#   'shirt',
#   'come',
#   'kid',
#   'size'],
#  ['hottti',
#   'poooh',
#   'ooo',
#   'bet',
#   'sounda',
#   'magic',
#   'hh',
#   'im',
#   'come',
#   'home',
#   'hour'],
#  ['go', 'bro', 'tonight', 'brett'],
#  ['think',
#   'may',
#   'broke',
#   'toe',
#   'bar',
#   'tonightthank',
#   'drunk',
#   'girl',
#   'steppin',
#   'me'],
#  ['wow', 'car', 'awesom', 'fun', 'alex'],
#  ['realli', 'want', 'go', 'surfer', 'today'],
#  ['cant', 'get', 'onto', 'twitter', 'internet'],
#  ['get',
#   'readi',
#   'launch',
#   'podcast',
#   'chapter',
#   'turn',
#   'left',
#   'albuquerqu',
#   'morn',
#   'know',
#   'excit'],
#  ['sad', 'day', 'christian', 'lacroix', 'file', 'bankruptci'],
#  ['muck', 'guitar', 'rig', 'demo'],
#  ['wait',
#   'red',
#   'could',
#   'age',
#   'know',
#   'mean',
#   'though',
#   'realli',
#   'look',
#   'new',
#   'job'],
#  ['bad', 'sort', 'want', 'miss', 'me', 'know', 'miss', 'her'],
#  ['laugh',
#   'loud',
#   'ik',
#   'are',
#   'figur',
#   'ive',
#   'kept',
#   'year',
#   'without',
#   'need',
#   'viru',
#   'softwar',
#   'get',
#   'fix',
#   'sigh'],
#  ['hate', 'headrush'],
#  ['bgt', 'gut', 'finish', 'tomorrow', 'stavro', 'flatley', 'way'],
#  ['happi', 'mother', 'day'],
#  ['trueli',
#   'sad',
#   'news',
#   'hear',
#   'creat',
#   'equal',
#   'sad',
#   'know',
#   'neighbor',
#   'prejudic',
#   'peopl'],
#  ['hey', 'back', 'robluket', 'live'],
#  ['yeah', 'haha', 'rd', 'episod', 'well'],
#  ['pleas'],
#  ['go', 'home', 'meet', 'today'],
#  ['out', 'get', 'memo', 'look', 'amaz'],
#  ['hope', 'itll', 'go', 'quickli', 'possibl'],
#  ['lost', 'game', 'point'],
#  ['got', 'jojo', 'free', 'free', 'drink', 'mom', 'kind', 'night'],
#  ['love', 'mini'],
#  ['that',
#   'awesom',
#   'weekend',
#   'cant',
#   'go',
#   'move',
#   'sat',
#   'lot',
#   'fun',
#   'though'],
#  ['hime',
#   'play',
#   'latter',
#   'part',
#   'voodoo',
#   'villag',
#   'part',
#   'coop',
#   'lost',
#   'usual',
#   'partner'],
#  ['mind',
#   'tell',
#   'book',
#   'cuz',
#   'barn',
#   'nobl',
#   'today',
#   'found',
#   'book',
#   'look',
#   'promis'],
#  ['haha', 'aww', 'ok', 'back', 'bionomi', 'expans', 'ugh', 'joy'],
#  ['dude', 'dia', 'eu', 'tenho', 'curso', 'na', 'drc', 'flash', 'expert'],
#  ['holiday',
#   'tear',
#   'eye',
#   'got',
#   'grizzli',
#   'bear',
#   'cd',
#   'bit',
#   'wont',
#   'read',
#   'adventur',
#   'tomorrow',
#   'swine',
#   'flu',
#   'scare',
#   'still',
#   'cold'],
#  ['ok', 'know', 'daisi', 'love', 'seen', 'yet', 'oh', 'lord'],
#  ['where',
#   'yummiest',
#   'pan',
#   'mee',
#   'behind',
#   'danc',
#   'center',
#   'ipoh',
#   'garden',
#   'south',
#   'miss'],
#  ['thank', 'ff', 'friend'],
#  ['good', 'choic'],
#  ['awsom',
#   'salad',
#   'recommend',
#   'get',
#   'spicey',
#   'buffalo',
#   'chicken',
#   'salad'],
#  ['tell', 'ill', 'beat', 'doesnt', 'share'],
#  ['mother', 'day', 'sunday', 'forget', 'send', 'someth', 'special'],
#  ['knowledg', 'xmen', 'start', 'scare'],
#  ['prob', 'hun'],
#  ['id', 'respond', 'go'],
#  ['nope', 'done', 'yet'],
#  ['yup',
#   'us',
#   'too',
#   'spend',
#   'tear',
#   'eye',
#   'mom',
#   'si',
#   'aunt',
#   'great',
#   'mother',
#   'day'],
#  ['sky',
#   'got',
#   'sing',
#   'fall',
#   'love',
#   'now',
#   'onli',
#   'chang',
#   'week',
#   'day',
#   'saturday',
#   'quit',
#   'fit'],
#  ['uh', 'oh', 'gonna', 'fire', 'somebodi'],
#  ['least', 'doesnt', 'tri', 'violent', 'hump', 'like', 'femal', 'dog'],
#  ['hour',
#   'walk',
#   'hot',
#   'weather',
#   'satisfi',
#   'hurt',
#   'nelli',
#   'ow',
#   'blister'],
#  ['school', 'out', 'work'],
#  ['well',
#   'wassup',
#   'dont',
#   'scur',
#   'now',
#   'laugh',
#   'loud',
#   'probabl',
#   'like',
#   'came',
#   'bite'],
#  ['geez', 'cool', 'man', 'like', 'villain', 'bad'],
#  ['aww', 'guess', 'mani', 'peopl', 'onlin', 'though'],
#  ['let', 'queer', 'boy', 'donat', 'blood'],
#  ['fun',
#   'flashi',
#   'fed',
#   'hillim',
#   'sure',
#   'import',
#   'cheeto',
#   'eat',
#   'fit',
#   'laugh',
#   'loud'],
#  ['amaz', 'concert', 'got', 'realli', 'good', 'video', 'pictur'],
#  ['good', 'morn', 'all', 'welcom', 'new', 'follow'],
#  ['back', 'interest', 'email'],
#  ['phone',
#   'call',
#   'yet',
#   'minut',
#   'pluck',
#   'courag',
#   'wish',
#   'phone',
#   'would',
#   'ring'],
#  ['qood', 'morninq'],
#  ['yeah', 'ecpm', 'go', 'badli', 'hope', 'thing', 'improv'],
#  ['so', 'tmobil', 'hummer', 'wish', 'batteri', 'life', 'iphon'],
#  ['cannot', 'go', 'cannot', 'refus', 'feel', 'pain'],
#  ['trickeri',
#   'no',
#   'exasper',
#   'see',
#   'pride',
#   'hijack',
#   'polit',
#   'bigger',
#   'uglier',
#   'anyth',
#   'meant'],
#  ['tear',
#   'eye',
#   'wind',
#   'relax',
#   'littl',
#   'chang',
#   'world',
#   'littl',
#   'twitter',
#   'even',
#   'rest',
#   'other'],
#  ['awww', 'boo', 'love', 'girli', 'thingss'],
#  ['know', 'ef', 'embarrass', 'eff', 'live'],
#  ['accept',
#   'maid',
#   'applic',
#   'would',
#   'nice',
#   'start',
#   'first',
#   'thing',
#   'tomorrow',
#   'would',
#   'make',
#   'wonder',
#   'mother',
#   'day',
#   'present'],
#  ['yearl', 'pet', 'home', 'die', 'sad', 'whole', 'famili'],
#  ['aw', 'torn', 'ace', 'heart', 'hunchback'],
#  ['wonder',
#   'peopl',
#   'life',
#   'think',
#   'handl',
#   'small',
#   'dose',
#   'cud',
#   'everi',
#   'hour',
#   'everyday'],
#  ['rachel',
#   'alexandra',
#   'belmont',
#   'appear',
#   'vogu',
#   'best',
#   'look',
#   'model',
#   'theyv',
#   'year'],
#  ['surf', 'week', 'start', 'afternoon'],
#  ['think', 'found', 'purs', 'soulmat', 'budget'],
#  ['yeah', 'need', 'hugcuz', 'sick'],
#  ['empathis',
#   'luvvi',
#   'dont',
#   'person',
#   'understand',
#   'grown',
#   'man',
#   'need',
#   'dress',
#   'tartan',
#   'search',
#   'littl',
#   'white',
#   'ball'],
#  ['oh', 'ok', 'good', 'jump', 'joy', 'made', 'day'],
#  ['mummi', 'nathan', 'today', 'todd'],
#  ['miss',
#   'jack',
#   'box',
#   'whataburg',
#   'oooo',
#   'taco',
#   'cabanaaaaaa',
#   'laugh',
#   'ass'],
#  ['sometim',
#   'hurt',
#   'pet',
#   'cant',
#   'talk',
#   'back',
#   'us',
#   'pain',
#   'would',
#   'tell',
#   'us'],
#  ['one', 'onlin'],
#  ['aww', 'peopl', 'must', 'color', 'blind', 'huh', 'random'],
#  ['sad', 'cant', 'go', 'friend', 'hous'],
#  ['bore', 'heheh', 'hate', 'ipt'],
#  ['hope', 'go', 'red', 'lobster', 'weekend'],
#  ['sh',
#   'get',
#   'even',
#   'sad',
#   'current',
#   'librari',
#   'think',
#   'itll',
#   'last',
#   'one',
#   'tooooo'],
#  ['hi',
#   'bunni',
#   'recent',
#   'subcrib',
#   'channel',
#   'youtub',
#   'make',
#   'great',
#   'stuff',
#   'kinda',
#   'want',
#   'say',
#   'hi'],
#  ['summer',
#   'glau',
#   'appear',
#   'dollhous',
#   'next',
#   'year',
#   'still',
#   'cant',
#   'believ',
#   'renew',
#   'tscc'],
#  ['want', 'bad', 'go', 'mcfli', 'concert', 'anybodi', 'go', 'me'],
#  ['look',
#   'old',
#   'stuff',
#   'found',
#   'record',
#   'old',
#   'band',
#   'wella',
#   'band',
#   'month',
#   'ever',
#   'heard'],
#  ['myst', 'soooo', 'disappoint', 'look', 'like', 'btw', 'imag', 'gone'],
#  ['drive',
#   'mph',
#   'daili',
#   'basi',
#   'cld',
#   'film',
#   'fast',
#   'furiou',
#   'me',
#   'anyth',
#   'mph',
#   'fort',
#   'bump',
#   'anyth'],
#  ['today', 'sooo', 'bore', 'school', 'sleep', 'tear', 'eye'],
#  ['feel', 'sooo', 'close', 'hard', 'cant', 'point', 'ugh'],
#  ['tom',
#   'gig',
#   'tonight',
#   'sorri',
#   'im',
#   'sure',
#   'show',
#   'there',
#   'miss',
#   'uk',
#   'hi',
#   'hi',
#   'hi',
#   'hi',
#   'hi'],
#  ['yeah',
#   'made',
#   'great',
#   'nois',
#   'trip',
#   'hous',
#   'circuit',
#   'breaker',
#   'good',
#   'time',
#   'worth',
#   'part'],
#  ['tri', 'play', 'john', 'travolta', 'greas', 'lightn', 'basslin', 'cool'],
#  ['like', 'himym'],
#  ['bum',
#   'laugh',
#   'loud',
#   'minut',
#   'slow',
#   'sec',
#   'fun',
#   'tear',
#   'old',
#   'poster',
#   'put',
#   'new',
#   'one'],
#  ['webcam', 'hoepfner', 'burgfest', 'karlsruh', 'automat', 'reload', 'fail'],
#  ['husband', 'wear', 'shirt', 'time', 'think', 'send', 'way'],
#  ['stress', 'beyond', 'belief', 'need', 'nap'],
#  ['dahh', 'believ', 'tear', 'eye', 'bed', 'gnight'],
#  ['see', 'saturday'],
#  ['mayb',
#   'get',
#   'statu',
#   'sainthood',
#   'seek',
#   'winwin',
#   'all',
#   'cant',
#   'victim',
#   'like',
#   'peopl'],
#  ['go', 'fold', 'laundri', 'hit', 'sack', 'bore', 'saturday', 'even'],
#  ['want', 'hang', 'friend', 'soon'],
#  ['upload',
#   'new',
#   'blog',
#   'pain',
#   'stori',
#   'year',
#   'old',
#   'man',
#   'cri',
#   'want',
#   'die',
#   'sad'],
#  ['still', 'wait', 'email', 'max', 'consid', 'news', 'bad', 'news'],
#  ['stunningli',
#   'beauti',
#   'new',
#   'piec',
#   'usual',
#   'go',
#   'togeth',
#   'wish',
#   'could',
#   'go'],
#  ['went',
#   'friend',
#   'hous',
#   'watch',
#   'good',
#   'old',
#   'season',
#   'episod',
#   'supernatur',
#   'love',
#   'show',
#   'soo',
#   'much'],
#  ['nana',
#   'nana',
#   'rock',
#   'rhineston',
#   'print',
#   'onesi',
#   'my',
#   'nana',
#   'love',
#   'me'],
#  ['keep', 'think', 'food', 'made', 'tea'],
#  ['itlesson', 'school', 'eat', 'salad'],
#  ['love',
#   'plan',
#   'cancel',
#   'night',
#   'anoth',
#   'night',
#   'home',
#   'alon',
#   'me',
#   'unyay'],
#  ['last',
#   'repli',
#   'scholar',
#   'us',
#   'homeland',
#   'secur',
#   'said',
#   'ontolog',
#   'creat',
#   'and',
#   'everybodi',
#   'hate',
#   'it',
#   'prescript'],
#  ['news',
#   'flash',
#   'megaredpacket',
#   'instant',
#   'internet',
#   'empir',
#   'earli',
#   'bird',
#   'launch',
#   'check',
#   'deal'],
#  ['hate',
#   'live',
#   'fl',
#   'miss',
#   'ga',
#   'like',
#   'crazylik',
#   'say',
#   'dont',
#   'know',
#   'got',
#   'till',
#   'gone',
#   'ga',
#   'mind'],
#  ['fun',
#   'viper',
#   'room',
#   'tomorrow',
#   'night',
#   'know',
#   'fam',
#   'attend',
#   'support',
#   'yall'],
#  ['realiz', 'solid', 'better', 'fullpag', 'ajc'],
#  ['snap', 'realiti', 'show', 'watch', 'first', 'hook', 'sad'],
#  ['soo', 'sick', 'wade', 'mood', 'swing', 'uhh', 'hate', 'him', 'he', 'ahhhh'],
#  ['wow',
#   'ive',
#   'join',
#   'photographi',
#   'scene',
#   'pretti',
#   'recent',
#   'larg',
#   'format',
#   'make',
#   'even',
#   'interest'],
#  ['never', 'anyth', 'tv', 'sunday', 'cant', 'wait', 'america'],
#  ['isnt', 'im'],
#  ['know', 'exactli', 'mean', 'treat', 'awhil', 'onc', 'in'],
#  ['nice', 'weatherlook', 'like', 'go', 'rain', 'delhi'],
#  ['feel', 'way', 'guess', 'matter', 'alway', 'meme'],
#  ['im', 'fail', 'class', 'algebra', 'hard'],
#  ['want', 'hit'],
#  ['star', 'review', 'canada', 'least', 'talk', 'like', 'canadian', 'incid'],
#  ['horribl', 'toothach', 'wink', 'sleep'],
#  ['illi',
#   'note',
#   'book',
#   'from',
#   'one',
#   'geek',
#   'anoth',
#   'keep',
#   'good',
#   'work',
#   'sigh',
#   'miss',
#   'great',
#   'espresso'],
#  ['got', 'virgin', 'yet', 'sure', 'can', 'tbh', 'thank', 'anyway'],
#  ['around',
#   'littl',
#   'earlier',
#   'want',
#   'phone',
#   'rang',
#   'am',
#   'exercis',
#   'good',
#   'way',
#   'start',
#   'day',
#   'right'],
#  ['dude', 'realli', 'bachelor', 'point', 'worri', 'it'],
#  ['wow', 'slept', 'dolidh', 'wake'],
#  ['back', 'home', 'tallcre', 'rez', 'cant', 'see', 'boyfriend'],
#  ['english', 'exam', 'bleh', 'hate', 'vocab'],
#  ['okayjust', 'eat', 'cooki', 'share', 'laugh', 'loud'],
#  ['awwww', 'bless', 'need', 'anoth', 'chanc'],
#  ['feel', 'like', 'reboot', 'osx', 'support', 'hibern', 'reboot', 'bootcamp'],
#  ['day',
#   'cool',
#   'lil',
#   'twist',
#   'spam',
#   'twitter',
#   'like',
#   'last',
#   'week',
#   'tho'],
#  ['pffffffffff', 'triumph', 'cuz', 'gone', 'nap', 'lmao'],
#  ['arent', 'follow', 'me', 'cant', 'send', 'dm'],
#  ['chicago', 'rock', 'sock'],
#  ['awpoor', 'thing'],
#  ['meant', 'said', 'skin', 'terribl', 'plu', 'sunburnt', 'chest'],
#  ['wowi', 'mani', 'bookmarksi', 'spent', 'good', 'hour', 'organ'],
#  ['romanc', 'zero', 'funni'],
#  ['tear',
#   'eye',
#   'go',
#   'bed',
#   'hope',
#   'wake',
#   'better',
#   'day',
#   'niiiiiiiight',
#   'yall'],
#  ['less', 'rain', 'sunshin'],
#  ['that', 'cold'],
#  ['want', 'learn', 'make', 'flower'],
#  ['anoth',
#   'day',
#   'find',
#   'you',
#   'end',
#   'tri',
#   'anoth',
#   'cart',
#   'cant',
#   'rememb',
#   'name',
#   'sigh'],
#  ['glass', 'cold', 'water', 'medit', 'bit'],
#  ['feel', 'guilti', 'like', 'revis', 'stuff', 'today', 'haha'],
#  ['need', 'simpl', 'reminderthx'],
#  ['umm',
#   'here',
#   'appl',
#   'pie',
#   'check',
#   'cupcak',
#   'check',
#   'green',
#   'tea',
#   'check',
#   'coffe',
#   'check',
#   'were',
#   'readi',
#   'tea',
#   'tear',
#   'eye'],
#  ['ye', 'ubook', 'lenovo', 'final', 'arriv'],
#  ['oh', 'man', 'dead', 'deer', 'everywher', 'michigan'],
#  ['expect', 'warm', 'usual', 'stuck', 'wear', 'sun', 'dress', 'cold', 'day'],
#  ['health', 'insur', 'option'],
#  ['victor',
#   'drew',
#   'hannah',
#   'montanna',
#   'yearbookhahaha',
#   'go',
#   'miss',
#   'nd',
#   'per',
#   'much'],
#  ['make', 'mind'],
#  ['bore', 'noth'],
#  ['dog', 'die', 'today', 'year', 'miss', 'much'],
#  ['thank', 'come', 'tonight', 'made', 'happi'],
#  ['talk', 'sinc', 'last', 'day', 'school', 'that', 'right'],
#  ['happi', 'mother', 'mom', 'there'],
#  ['happi', 'mother', 'day', 'mother', 'there'],
#  ['munch', 'high', 'calori', 'thing', 'keep', 'brain', 'work'],
#  ['gossip',
#   'fluffodil',
#   'here',
#   'latest',
#   'mad',
#   'night',
#   'teg',
#   'jack',
#   'lou',
#   'tess',
#   'frey',
#   'gender',
#   'war',
#   'sad',
#   'friend',
#   'also'],
#  ['ye', 'new', 'one', 'ador', 'though', 'love', 'vincent'],
#  ['think',
#   'haircut',
#   'isnt',
#   'bad',
#   'look',
#   'yesterday',
#   'still',
#   'bad',
#   'tho'],
#  ['could', 'lost', 'dog', 'poor', 'girl'],
#  ['hey',
#   'im',
#   'fan',
#   'new',
#   'zealand',
#   'love',
#   'show',
#   'even',
#   'tho',
#   'soooo',
#   'behind',
#   'episod',
#   'haha',
#   'keep',
#   'good',
#   'work'],
#  ['swear', 'dog', 'anxieti', 'issu'],
#  ['tri', 'watch', 'lost', 'onlin', 'annoy', 'slowth', 'internet', 'lost'],
#  ['tarrant', 'nice', 'momma', 'day'],
#  ['paradis',
#   'hi',
#   'dale',
#   'welcom',
#   'man',
#   'hope',
#   'ur',
#   'weekend',
#   'go',
#   'well',
#   'think',
#   'would',
#   'enjoy',
#   'desert',
#   'paradis',
#   'fun',
#   'fun',
#   'fun'],
#  ['roll', 'floor', 'laugh', 'uh', 'huh'],
#  ['thank',
#   'hun',
#   'wear',
#   'new',
#   'goldmin',
#   'es',
#   'big',
#   'fals',
#   'lash',
#   'show'],
#  ['say', 'mlia', 'instead', 'fml', 'hope', 'find', 'soon'],
#  ['friend',
#   'request',
#   'play',
#   'noth',
#   'sir',
#   'hit',
#   'perth',
#   'tue',
#   'jazz',
#   'charni'],
#  ['tonight',
#   'great',
#   'night',
#   'sport',
#   'yank',
#   'laker',
#   'play',
#   'want',
#   'watch',
#   'game',
#   'im',
#   'still',
#   'scare',
#   'drink'],
#  ['happi', 'sunday', 'beauti', 'day', 'london', 'meet', 'chergo', 'breakfast'],
#  ['wanna', 'watch', 'pcd', 'concert', 'dad'],
#  ['think',
#   'boat',
#   'sail',
#   'friend',
#   'cco',
#   'them',
#   'month',
#   'ago',
#   'wish',
#   'luck',
#   'though'],
#  ['angel', 'even', 'though', 'probabl', 'third', 'angel', 'demon'],
#  ['chick', 'wont', 'shut', 'stop', 'chirp', 'sit', 'bloodi', 'thing'],
#  ['happi', 'sunday', 'sunshin', 'frankfurt', 'hope', 'mother', 'enjoy', 'day'],
#  ['hope', 'feel', 'better', 'soon', 'littl', 'magic', 'girl'],
#  ['check', 'check', 'ye', 'and', 'am'],
#  ['like',
#   'abl',
#   'say',
#   'truth',
#   'instead',
#   'magic',
#   'mysteri',
#   'tour',
#   'get',
#   'led',
#   'on'],
#  ['talk', 'mom', 'al', 'sang', 'song', 'sleep', 'now'],
#  ['iã',
#   'â½m',
#   'jbobsess',
#   'xd',
#   'miss',
#   'soooooo',
#   'much',
#   'live',
#   'web',
#   'cast',
#   'bookfac',
#   'everi',
#   'thursday',
#   'xd'],
#  ['spent', 'minut', 'book', 'store', 'bought', 'one', 'book'],
#  ['cook', 'lunch', 'todayi', 'givin', 'mum', 'relaxin', 'dayi'],
#  ['awak', 'want', 'go', 'work'],
#  ['ugh', 'talk', 'someon', 'realli', 'bore'],
#  ['boss', 'la', 'vega', 'th', 'app', 'conferencepfff'],
#  ['were', 'english', 'well', 'part', 'weather', 'obsess'],
#  ['back', 'home', 'palmdal', 'bed', 'mommi'],
#  ['great',
#   'seein',
#   'guy',
#   'today',
#   'look',
#   'happi',
#   'love',
#   'it',
#   'let',
#   'hang',
#   'soon',
#   'love',
#   'yall'],
#  ['plan',
#   'road',
#   'trip',
#   'san',
#   'diego',
#   'detour',
#   'vega',
#   'celebr',
#   'birthday',
#   'bad',
#   'wk',
#   'away',
#   'want',
#   'go',
#   'now'],
#  ['honey', 'got', 'mad', 'yr', 'go', 'crazi'],
#  ['got', 'show', 'earli', 'jackson', 'chillen', 'lil', 'shorti'],
#  ['stupid',
#   'hand',
#   'flop',
#   'nut',
#   'low',
#   'top',
#   'pair',
#   'guy',
#   'also',
#   'low',
#   'flush',
#   'quarter'],
#  ['know', 'go', 'sort'],
#  ['hope',
#   'so',
#   'record',
#   'pitwa',
#   'game',
#   'find',
#   'didnt',
#   'record',
#   'lucki',
#   'leaf',
#   'woulda',
#   'lost'],
#  ['readi', 'set', 'hmmm', 'delay'],
#  ['need', 'go', 'bike', 'ride'],
#  ['chanc', 'madison', 'wi', 'locat', 'soon', 'mayb', 'small'],
#  ['kay', 'plant', 'garden', 'last', 'week', 'ive', 'got', 'check'],
#  ['know', 'roger', 'pretti', 'sure', 'agreement', 'twitter'],
#  ['would',
#   'you',
#   'pay',
#   'lunch',
#   'oscar',
#   'de',
#   'la',
#   'renta',
#   'see',
#   'hit',
#   'east',
#   'villag',
#   'shop',
#   'you'],
#  ['cindi', 'babi', 'housetak', 'last', 'friday', 'togeth', 'dr', 'hope'],
#  ['love',
#   'tooooo',
#   'duuudei',
#   'need',
#   'make',
#   'shirt',
#   'say',
#   'someth',
#   'cool',
#   'say'],
#  ['love'],
#  ['use', 'onscreen', 'keyboard'],
#  ['fiftythousand', 'follow', 'hugh', 'lauri', 'needl', 'haystack', 'now'],
#  ['morn',
#   'ali',
#   'big',
#   'thank',
#   'yesterday',
#   'love',
#   'alway',
#   'xxxx',
#   'bike',
#   'today',
#   'forget',
#   'get',
#   'helmet',
#   'ok'],
#  ['wordsaftersex', 'goodby', 'innoc'],
#  ['realli', 'smoke'],
#  ['creativ', 'vado', 'stock', 'walmartcom', 'miss', 'it', 'thank', 'tweet'],
#  ['thnkn',
#   'bout',
#   'yesterdaybest',
#   'day',
#   'ever',
#   'day',
#   'virtu',
#   'vs',
#   'treviso',
#   'da',
#   'futurshowhard',
#   'gamegotta',
#   'win',
#   'forza',
#   'ragazzi'],
#  ['head', 'hurt', 'bad'],
#  ['nicol', 'exact', 'pic', 'except', 'hubbi', 'chihuahua', 'tucker', 'cute'],
#  ['wifeyyyyyi', 'likey', 'siki'],
#  ['also',
#   'paracetamol',
#   'hard',
#   'swallow',
#   'even',
#   'long',
#   'one',
#   'snap',
#   'half',
#   'ow'],
#  ['clair', 'sunni', 'send'],
#  ['almost', 'lost', 'phone'],
#  ['mean', 'make', 'sad'],
#  ['im', 'bore', 'rc', 'goin', 'mainten'],
#  ['hmmyour', 'blog', 'let', 'post', 'comment'],
#  ['hope', 'great', 'weekend', 'congratul'],
#  ['and',
#   'syke',
#   'lose',
#   'gig',
#   'gain',
#   'better',
#   'one',
#   'frankli',
#   'best',
#   'thing',
#   'rightard',
#   'scream',
#   'thi'],
#  ['benson', 'absolut', 'legend', 'love', 'love', 'love'],
#  ['woke',
#   'delight',
#   'nap',
#   'cant',
#   'desrib',
#   'much',
#   'success',
#   'involv',
#   'am',
#   'nap',
#   'sat',
#   'nightne',
#   'rhubarb'],
#  ['scari',
#   'lightn',
#   'thunder',
#   'glad',
#   'now',
#   'go',
#   'sleep',
#   'hope',
#   'late',
#   'school',
#   'tomorow',
#   'again',
#   'haha'],
#  ['late', 'nightfin', 'home'],
#  ['ps', 'sorri', 'ur', 'uncl'],
#  ['tooth', 'bloodi', 'kill', 'sure', 'wait', 'next', 'week', 'get', 'fix'],
#  ['bad'],
#  ['realli', 'realli', 'readi'],
#  ['easyjust', 'turn', 'keyboard', 'upsid'],
#  ['chang', 'car', 'tire', 'cost', 'bomb'],
#  ['mayb', 'lack', 'friday', 'feel', 'co', 'trouser', 'go', 'thunder', 'thigh'],
#  ['want', 'trade', 'someon', 'houston', 'ticket', 'one', 'will'],
#  ['jumpstart',
#   'wotd',
#   'jape',
#   'qq',
#   'comppetit',
#   'overcompetit',
#   'competit',
#   'all',
#   'write',
#   'respons',
#   'here'],
#  ['home', 'get', 'readi', 'back', 'work', 'monday', 'matern', 'leav'],
#  ['lurveeeee'],
#  ['check', 'work', 'sorri'],
#  ['includ', 'chotachota', 'stuff', 'releas', 'reflexi', 'arcad', 'too'],
#  ['hypnot', 'oh', 'thanx', 'thought', 'ilost', 'it', 'iappreci'],
#  ['safe', 'flight'],
#  ['deplurk', 'too', 'buhbyee'],
#  ['great', 'mother', 'day'],
#  ['graduat', 'next', 'sunday', 'im', 'go', 'miss', 'class'],
#  ['weekend',
#   'bought',
#   'lost',
#   'odyssey',
#   'yay',
#   'howev',
#   'rrode',
#   'second',
#   'tear',
#   'eye'],
#  ['annoy', 'miss', 'mitch', 'benn', 'lemon', 'tree', 'what', 'on'],
#  ['th', 'updat'],
#  ['poor',
#   'stuart',
#   'wonder',
#   'wa',
#   'move',
#   'day',
#   'todayi',
#   'expect',
#   'welcom',
#   'cake',
#   'case',
#   'neighbor',
#   'heheh'],
#  ['hey', 'bow', 'yu', 'comin', 'baxx', 'thaa', 'miss', 'yu', 'hun', 'day'],
#  ['life', 'suck'],
#  ['tire',
#   'tire',
#   'tire',
#   'sleep',
#   'well',
#   'last',
#   'night',
#   'thought',
#   'much',
#   'slept',
#   'much',
#   'glad',
#   'almost',
#   'weekend'],
#  ['pictur', 'last', 'year', 'freshman', 'year', 'miss', 'tho', 'day'],
#  ['haha',
#   'stop',
#   'here',
#   'not',
#   'go',
#   'turn',
#   'section',
#   'ohwel',
#   'parent',
#   'came',
#   'home'],
#  ['math', 'quiz', 'meow', 'allergi', 'meow', 'allergi'],
#  ['hope', 'fun', 'tonight'],
#  ['sometim',
#   'forget',
#   'favorit',
#   'star',
#   'real',
#   'peopl',
#   'too',
#   'made',
#   'orang',
#   'chicken',
#   'last',
#   'night',
#   'cut',
#   'finger',
#   'off',
#   'sad'],
#  ['sit', 'comput', 'eat', 'grape', 'hail', 'outsid', 'miss', 'summer'],
#  ['ice', 'cream'],
#  ['printchick',
#   'exactli',
#   'that',
#   'first',
#   'tear',
#   'eye',
#   'saw',
#   'repli',
#   'jon',
#   'never',
#   'go',
#   'again',
#   'oh',
#   'fun',
#   'new',
#   'phone'],
#  ['what', 'up', 'im', 'sad', 'didnt', 'text', 'today'],
#  ['content', 'life', 'moment'],
#  ['sit',
#   'mr',
#   'martin',
#   'class',
#   'youtub',
#   'stupid',
#   'realli',
#   'want',
#   'popsicl',
#   'jealou',
#   'sara'],
#  ['soooo',
#   'bum',
#   'miss',
#   'blockparti',
#   'again',
#   'abl',
#   'get',
#   'app',
#   'listen',
#   'iphon'],
#  ['last', 'day', 'profession', 'intern'],
#  ['next', 'singl', 'hey', 'ladyok', 'million', 'dollar'],
#  ['day', 'cellstorm', 'like', 'it'],
#  ['sad', 'tea', 'oatmeal', 'cold'],
#  ['hey',
#   'wanda',
#   'great',
#   'tweet',
#   'mani',
#   'thank',
#   'info',
#   'dobro',
#   'fantast',
#   'sound',
#   'son',
#   'hous',
#   'fav',
#   'mine'],
#  ['work',
#   'secur',
#   'club',
#   'tonight',
#   'first',
#   'tear',
#   'eye',
#   'work',
#   'month',
#   'interest',
#   'oh',
#   'hi',
#   'kelsen'],
#  ['kaylale', 'think', 'one', 'know', 'number', 'mean', 'laugh', 'loud'],
#  ['first', 'thought', 'too', 'ive', 'never', 'even', 'watch', 'dragonbal'],
#  ['wow',
#   'cant',
#   'believ',
#   'monday',
#   'alreadi',
#   'hope',
#   'everyon',
#   'well',
#   'today'],
#  ['thank',
#   'wish',
#   'luck',
#   'coupl',
#   'week',
#   'ago',
#   'get',
#   'higher',
#   'choir',
#   'make'],
#  ['pleas', 'comment', 'back', 'love'],
#  ['colossu', 'lol', 'cheer', 'mate', 'yeah', 'went', 'well', 'thank'],
#  ['went',
#   'bought',
#   'bigest',
#   'redbul',
#   'could',
#   'find',
#   'go',
#   'long',
#   'day',
#   'offic'],
#  ['okay', 'idea'],
#  ['know',
#   'keep',
#   'wild',
#   'dog',
#   'els',
#   'abl',
#   'situat',
#   'use',
#   'mandriva',
#   'life'],
#  ['listen',
#   'darren',
#   'hayess',
#   'spin',
#   'talkin',
#   'wacki',
#   'friend',
#   'who',
#   'go',
#   'insan',
#   'aint',
#   'tire',
#   'mess',
#   'bout',
#   'thing'],
#  ['leav',
#   'minneapoli',
#   'homework',
#   'go',
#   'watch',
#   'brother',
#   'tenni',
#   'match',
#   'later'],
#  ['back', 'work', 'go'],
#  ['wait', 'line', 'beast', 'matthew', 'ride'],
#  ['photo',
#   'hannahisdead',
#   'omg',
#   'wanna',
#   'read',
#   'pride',
#   'prejudic',
#   'zombi',
#   'fuckyeah',
#   'zombi'],
#  ['love', 'clutch', 'lust', 'one', 'bright', 'yellow'],
#  ['go',
#   'drink',
#   'mojito',
#   'lay',
#   'watch',
#   'movi',
#   'hubbi',
#   'goodnight',
#   'fellow',
#   'tweeter'],
#  ['go', 'sadli', 'mayb', 'next', 'year', 'eh'],
#  ['aaaw',
#   'that',
#   'sweet',
#   'him',
#   'girl',
#   'friend',
#   'got',
#   'drag',
#   'hubbi',
#   'niteout',
#   'unless',
#   'beer',
#   'laugh',
#   'loud'],
#  ['sooo', 'happi', 'demi', 'back', 'twitter'],
#  ['yeeeee',
#   'haha',
#   'funniest',
#   'thing',
#   'dude',
#   'cant',
#   'ball',
#   'bring',
#   'hot',
#   'gf',
#   'along',
#   'watch',
#   'get',
#   'murk'],
#  ['mose', 'girlfriend', 'broke', 'up'],
#  ['agre',
#   'facehunt',
#   'embarrass',
#   'represent',
#   'compar',
#   'swede',
#   'look',
#   'like',
#   'born',
#   'stylish'],
#  ['bore', 'internet', 'made', 'downtown', 'beach', 'yet'],
#  ['good',
#   'morn',
#   'everyon',
#   'nice',
#   'day',
#   'iloveitwhen',
#   'sun',
#   'shine',
#   'go',
#   'write',
#   'stuff'],
#  ['rememb', 'show', 'rememb', 'hiccup'],
#  ['woke', 'up', 'walk', 'room', 'bug', 'flew', 'eye'],
#  ['hi', 'anyon', 'there'],
#  ['no', 'whi'],
#  ['drop', 'mum', 'station', 'ill', 'miss', 'mum'],
#  ['laugh', 'loud', 'stay', 'hour', 'keep', 'miss', 'tila', 'last', 'post'],
#  ['work',
#   'earli',
#   'frustrat',
#   'work',
#   'get',
#   'frustrat',
#   'work',
#   'much',
#   'tear',
#   'eye',
#   'design',
#   'today'],
#  ['morn', 'that', 'mean', 'that', 'smart'],
#  ['hmmm',
#   'skip',
#   'groceri',
#   'store',
#   'head',
#   'walmart',
#   'could',
#   'potenti',
#   'leav',
#   'much',
#   'more'],
#  ['bedsorta',
#   'today',
#   'good',
#   'sara',
#   'strep',
#   'thought',
#   'angelina',
#   'to',
#   'share',
#   'water',
#   'told',
#   'me',
#   'prob',
#   'get'],
#  ['took',
#   'shift',
#   'tomorrow',
#   'realli',
#   'feel',
#   'like',
#   'work',
#   'right',
#   'now'],
#  ['great',
#   'honey',
#   'base',
#   'recip',
#   'kid',
#   'download',
#   'join',
#   'fun',
#   'honey',
#   'week'],
#  ['hi', 'mel', 'feel', 'unhappi', 'take', 'bit', 'fri', 'overdo', 'help'],
#  ['migrain', 'fight', 'way', 'back', 'last', 'night'],
#  ['sad', 'new', 'sb', 'cd', 'got', 'nick'],
#  ['cant', 'get', 'bed'],
#  ['how', 'head', 'morn'],
#  ['say', 'everyon', 'busi'],
#  ['hahah', 'sowwi', 'hun', 'what', 'thoe'],
#  ['happi',
#   'star',
#   'war',
#   'daym',
#   'jaja',
#   'bink',
#   'ha',
#   'crappi',
#   'day',
#   'outsid',
#   'though',
#   'ah',
#   'well',
#   'make',
#   'bit',
#   'motiv',
#   'revis'],
#  ['swine', 'flu', 'victim', 'unit'],
#  ['deb', 'email', 'get', 'peopl', 'want', 'site', 'shame', 'trouser'],
#  ['tgif',
#   'also',
#   'sad',
#   'last',
#   'day',
#   'get',
#   'work',
#   'favorit',
#   'tv',
#   'report'],
#  ['hey',
#   'old',
#   'write',
#   'avoid',
#   'write',
#   'continu',
#   'flow',
#   'non',
#   'stop',
#   'minstrick',
#   'use',
#   'loosen',
#   'gremlin'],
#  ['feel', 'strong', 'contract', 'want', 'go', 'out'],
#  ['keep',
#   'pull',
#   'knit',
#   'desk',
#   'put',
#   'back',
#   'good',
#   'good',
#   'tminu',
#   'minut',
#   'till',
#   'releas'],
#  ['hot',
#   'done',
#   'late',
#   'spring',
#   'clean',
#   'settl',
#   'book',
#   'bare',
#   'read',
#   'left',
#   'glass',
#   'mum'],
#  ['houdin', 'blind', 'faith', 'that', 'crackup'],
#  ['pack',
#   'clean',
#   'get',
#   'done',
#   'last',
#   'day',
#   'apart',
#   'tear',
#   'eye',
#   'tomorrow',
#   'storag'],
#  ['final', 'someon', 'recogn', 'geniu'],
#  ['callmecourt', 'alway', 'welcom', 'hun'],
#  ['done',
#   'mother',
#   'daypeopl',
#   'day',
#   'behind',
#   'uswhat',
#   'do',
#   'took',
#   'mom',
#   'starbuck',
#   'enjoy'],
#  ['well', 'littl', 'bit', 'sick', 'fine'],
#  ['feel', 'sick', 'headach', 'bore', 'tireddd'],
#  ['toast', 'morn'],
#  ['may', 'email', 'tech', 'support', 'ppl', 'that', 'odd'],
#  ['ten', 'hour', 'ago', 'sleep', 'sorri'],
#  ['ever', 'barr', 'chord'],
#  ['bird', 'out', 'oh', 'man', 'that', 'cool', 'sleep', 'yet', 'night'],
#  ['ye', 'dear', 'opff', 'bbl'],
#  ['work', 'mercedez', 'last', 'day'],
#  ['rogã', 'â½rio', 'minotouro', 'fight', 'now'],
#  ['bloggerif',
#   'ha',
#   'nice',
#   'tri',
#   'outright',
#   'deni',
#   'accus',
#   'good',
#   'luck',
#   'that'],
#  ['want', 'see', 'stori', 'acorn', 'tonight', 'glen', 'beck', 'miss'],
#  ['ive',
#   'wonder',
#   'rake',
#   'to',
#   'client',
#   'made',
#   'clear',
#   'net',
#   'onli',
#   'forc',
#   'dev',
#   'learn',
#   'new',
#   'lang',
#   'agil',
#   'ccnet'],
#  ['too', 'pleas', 'come', 'onlin', 'hope', 'amaz', 'weekend'],
#  ['well', 'look', 'who', 'tweet'],
#  ['morn', 'tweepl'],
#  ['happi', 'mother', 'day', 'ur', 'mom', 'hope', 'wonder', 'day'],
#  ['chillin',
#   'break',
#   'eatin',
#   'grub',
#   'pretti',
#   'burnt',
#   'event',
#   'day',
#   'want',
#   'go',
#   'movi',
#   'ian',
#   'happen',
#   'though'],
#  ['cant',
#   'wait',
#   'hear',
#   'new',
#   'album',
#   'sure',
#   'amazingpleas',
#   'replay',
#   'love',
#   'much'],
#  ['how', 'new', 'gphone', 'guess', 'sign', 'go', 'googl', 'io'],
#  ['good', 'morn', 'good', 'luck', 'beliv'],
#  ['ooooh', 'laugh', 'loud', 'know', 'fun', 'princess'],
#  ['born'],
#  ['hahah',
#   'wish',
#   'true',
#   'realli',
#   'realli',
#   'bad',
#   'gonna',
#   'stay',
#   'home',
#   'chill',
# ...
#  ['sorri',
#   'miss',
#   'saw',
#   'across',
#   'way',
#   'busi',
#   'take',
#   'pixabt',
#   'came',
#   'meet',
#   'ubut',
#   'gone'],
#  ['wish', 'still', 'cornwal', 'miss', 'aunti', 'dog'],
#  ['depend', 'drink', 'drink', 'mani', 'mate', 'have', 'joke', 'fail'],
#  ['word', 'left', 'write', 'assign'],
#  ['ooohi',
#   'wish',
#   'couldv',
#   'gone',
#   'today',
#   'too',
#   'know',
#   'zach',
#   'look',
#   'forward',
#   'it'],
#  ['dread', 'go', 'work', 'butit', 'friiiiiday', 'whoop'],
#  ['oh',
#   'im',
#   'also',
#   'friend',
#   'im',
#   'me',
#   'realli',
#   'suck',
#   'alway',
#   'around'],
#  ['girl', 'night', 'portland'],
#  ['cool', 'wear', 'black', 'tear', 'eye', 'go'],
#  ['anytim', 'buddi'],
#  ['eat',
#   'bbq',
#   'jalapeno',
#   'torta',
#   'subway',
#   'lo',
#   'chaparro',
#   'right',
#   'next',
#   'door'],
#  ['work', 'allll', 'weeekend'],
#  ['that', 'great', 'news'],
#  ['tri', 'buy', 'new', 'biblebut', 'samewhi', 'dog', 'chew', 'up'],
#  ['teeshirt', 'faaar', 'small', 'like', 'much', 'stop', 'wear'],
#  ['friend',
#   'roman',
#   'countri',
#   'men',
#   'laugh',
#   'loud',
#   'ppl',
#   'need',
#   'help',
#   'say',
#   'twitter',
#   'dont',
#   'friend',
#   'loner',
#   'loner',
#   'la',
#   'da',
#   'da'],
#  ['appar',
#   'looong',
#   'tear',
#   'eye',
#   'see',
#   'seem',
#   'everywher',
#   'except',
#   'la'],
#  ['tell', 'grandmoth', 'say', 'hello'],
#  ['happi', 'star', 'war', 'day'],
#  ['ugh', 'back', 'reno'],
#  ['bed', 'sore'],
#  ['stop', 'believ', 'remix', 'sure', 'not', 'sacrileg'],
#  ['giver',
#   'life',
#   'reward',
#   'taker',
#   'giver',
#   'make',
#   'taker',
#   'possibl',
#   'get',
#   'appreci',
#   'dow',
#   'get',
#   'taken'],
#  ['either'],
#  ['im', 'sadd', 'sancha', 'june', 'fail', 'gonna', 'chini'],
#  ['boo', 'im', 'lone', 'bore'],
#  ['tp', 'report'],
#  ['money', 'car'],
#  ['watch',
#   'coralin',
#   'last',
#   'night',
#   'realli',
#   'good',
#   'anim',
#   'excel',
#   'creativ',
#   'inspir'],
#  ['hollowbabesher', 'come', 'utter', 'shite', 'bgt', 'complet', 'agre'],
#  ['wait', 'cue', 'kenni'],
#  ['think',
#   'not',
#   'girlfriend',
#   'need',
#   'douchebag',
#   'right',
#   'now',
#   'mood',
#   'feel',
#   'neglect'],
#  ['drop', 'lei', 'cemetari'],
#  ['massiv', 'headach', 'go', 'see', 'termin', 'tonight'],
#  ['today', 'horribl', 'dayi'],
#  ['sad',
#   'wish',
#   'could',
#   'stay',
#   'longer',
#   'last',
#   'tear',
#   'eye',
#   'ill',
#   'see',
#   'tonight',
#   'better',
#   'wear',
#   'make',
#   'up'],
#  ['mother', 'bad', 'day'],
#  ['learnt', 'drive', 'manual', 'weekend'],
#  ['sorri',
#   'love',
#   'left',
#   'over',
#   'come',
#   'sat',
#   'mi',
#   'casa',
#   'ton',
#   'birthday',
#   'well',
#   'ton',
#   'food'],
#  ['congrat'],
#  ['feel', 'lazi', 'watch', 'peopl', 'work', 'roof', 'kat', 'woman'],
#  ['cool',
#   'mother',
#   'awesom',
#   'hair',
#   'style',
#   'wish',
#   'happi',
#   'mother',
#   'day'],
#  ['morn', 'peopl', 'woke', 'now'],
#  ['amaz', 'happi', 'enjoy', 'sunday'],
#  ['come', 'straighten', 'hair', 'sprinkl'],
#  ['eat', 'tito', 'home', 'made', 'ice', 'cream', 'yum'],
#  ['definit', 'blast', 'past'],
#  ['hello', 'bank', 'holiday', 'monday', 'hello', 'revis', 'â½ã', 'â½'],
#  ['listen', 'song', 'myspac', 'realli', 'good'],
#  ['thank',
#   'god',
#   'sport',
#   'doesnt',
#   'take',
#   'offenc',
#   'joke',
#   'unlik',
#   'three',
#   'good',
#   'friend',
#   'stop',
#   'talk',
#   'me'],
#  ['well', 'thank', 'you'],
#  ['say', 'lo', 'page', 'doesnt', 'exist'],
#  ['awww', 'miss', 'then', 'ill', 'see', 'tonight'],
#  ['pleas', 'read', 'blog', 'best', 'day'],
#  ['watch',
#   'chicago',
#   'honeyyyi',
#   'im',
#   'miss',
#   'hey',
#   'arnold',
#   'wild',
#   'thornberri'],
#  ['work'],
#  ['roast', 'probabl', 'death'],
#  ['girl',
#   'ya',
#   'gotta',
#   'let',
#   'know',
#   'get',
#   'kit',
#   'togeth',
#   'got',
#   'flyer',
#   'next',
#   'weekend',
#   'down'],
#  ['ii', 'choic', 'get', 'it'],
#  ['summer', 'yet', 'read', 'book', 'long', 'book'],
#  ['what',
#   'next',
#   'movi',
#   'review',
#   'go',
#   'be',
#   'like',
#   'wossi',
#   'brum',
#   'controversi'],
#  ['hello', 'twit', 'world', 'best', 'buddi', 'bbq', 'until', 'jay', 'spotifi'],
#  ['look', 'find', 'amongst', 'crowd'],
#  ['fun', 'amorsot', 'even', 'tho', 'forgot', 'bday'],
#  ['hit', 'car', 'leav', 'note', 'yea', 'put', 'whatev', 'want', 'note'],
#  ['kind', 'bug', 'hous', 'dont', 'know'],
#  ['must', 'get', 'up'],
#  ['sole', 'support', 'sole', 'support'],
#  ['cant', 'spell', 'melo', 'without', 'favorit', 'blog', 'site'],
#  ['feel',
#   'like',
#   'hot',
#   'box',
#   'matter',
#   'go',
#   'still',
#   'feel',
#   'like',
#   'hot',
#   'box',
#   'ice',
#   'cream',
#   'work'],
#  ['thank', 'elain', 'clip', 'review', 'scrapbook'],
#  ['laugh',
#   'loud',
#   'birmingham',
#   'st',
#   'love',
#   'tear',
#   'eye',
#   'move',
#   'on',
#   'good',
#   'morn'],
#  ['twitter',
#   'reunion',
#   'would',
#   'awesom',
#   'meet',
#   'lol',
#   'iwond',
#   'howd',
#   'iget',
#   'pull'],
#  ['wide',
#   'awak',
#   'wish',
#   'wasnt',
#   'nightshift',
#   'routin',
#   'got',
#   'turn',
#   'job',
#   'nashvil',
#   'oh',
#   'well'],
#  ['been', 'laugh', 'loud'],
#  ['long',
#   'day',
#   'matine',
#   'even',
#   'show',
#   'sad',
#   'tomorrow',
#   'last',
#   'ever',
#   'welsh',
#   'colleg',
#   'show'],
#  ['diaper',
#   'feed',
#   'cook',
#   'stuff',
#   'hahaha',
#   'yeah',
#   'right',
#   'sound',
#   'like',
#   'normal',
#   'day',
#   'me'],
#  ['way', 'lake', 'geneva', 'miss', 'laura'],
#  ['ye', 'mate', 'friday'],
#  ['life', 'hey', 'like', 'love', 'icarli', 'rock', 'youtub', 'account'],
#  ['ok', 'babe', 'gotta', 'go', 'back', 'work', 'tweet', 'later'],
#  ['nice', 'brunch', 'bay', 'thank', 'god', 'mommi'],
#  ['beat', 'heat', 'cool', 'guava', 'juic', 'handi', 'water'],
#  ['think',
#   'might',
#   'like',
#   'twiterfon',
#   'better',
#   'tweeti',
#   'now',
#   'recent',
#   'upgrad',
#   'twiterfon',
#   'great',
#   'none',
#   'tweeti'],
#  ['friend',
#   'sent',
#   'call',
#   'bck',
#   'messag',
#   'dunno',
#   'could',
#   'repli',
#   'credit',
#   'tht',
#   'all'],
#  ['ill', 'visit', 'ny', 'til', 'septemb', 'diggnat'],
#  ['studi', 'like', 'crazi', 'hope', 'ace', 'exam'],
#  ['djing',
#   'prom',
#   'id',
#   'freether',
#   'prob',
#   'gonna',
#   'dj',
#   'who',
#   'stuck',
#   'boooooo'],
#  ['shite',
#   'night',
#   'tomorow',
#   'get',
#   'hang',
#   'littl',
#   'brother',
#   'neic',
#   'suffici',
#   'enough',
#   'chang',
#   'mood'],
#  ['sure',
#   'lot',
#   'studio',
#   'equip',
#   'collect',
#   'analog',
#   'stuff',
#   'cant',
#   'bought',
#   'anymor',
#   'serious',
#   'condol'],
#  ['hop', 'shower', 'help', 'tidi', 'room', 'hole', 'mum', 'friend'],
#  ['save', 'buy', 'couch', 'go', 'toward', 'pay', 'visit', 'er', 'uti'],
#  ['bore', 'noth'],
#  ['ouch', 'appli', 'ec', 'summer', 'graduat', 'then', 'hug'],
#  ['damm', 'it', 'get', 'pic', 'niamh', 'glass'],
#  ['like',
#   'cooki',
#   'go',
#   'love',
#   'cooki',
#   'lar',
#   'teten',
#   'cooki',
#   'is',
#   'come',
#   'see',
#   'us'],
#  ['well', 'tomorrow', 'miss'],
#  ['wish', 'day', 'day', 'peopl', 'want', 'parti'],
#  ['know', 'whi', 'lold'],
#  ['almost', 'everyon', 'suck', 'right', 'now', 'ive', 'peopl'],
#  ['lot', 'noisi', 'peep', 'outsid'],
#  ['haha', 'true', 'thank', 'regular', 'keyboard', 'job', 'time'],
#  ['place', 'bet', 'sure', 'thing', 'lost', 'bet', 'me'],
#  ['greek', 'season', 'two', 'love', 'show'],
#  ['may',
#   'cri',
#   'weather',
#   'got',
#   'burnt',
#   'nt',
#   'liter',
#   'ju',
#   'shin',
#   'arm',
#   'chest',
#   'leg',
#   'hurt',
#   'lyk',
#   'biatch',
#   'slightli',
#   'enjoy',
#   'tho',
#   'ha'],
#  ['song',
#   'know',
#   'especi',
#   'sinc',
#   'summer',
#   'bore',
#   'tv',
#   'tear',
#   'eye',
#   'begin',
#   'with'],
#  ['word', 'marlon', 'brando', 'gave', 'cent', 'yeah', 'tha', 'godfath'],
#  ['one', 'hour', 'till', 'go', 'home', 'commenc', 'pout', 'bahama', 'trip'],
#  ['hole',
#   'twitter',
#   'thing',
#   'new',
#   'me',
#   'let',
#   'chang',
#   'pictur',
#   'stuvk',
#   'wee',
#   'stpid',
#   'thing'],
#  ['quit',
#   'amus',
#   'watch',
#   'pangaea',
#   'sing',
#   'killah',
#   'priest',
#   'guess',
#   'featur',
#   'album'],
#  ['realli', 'want', 'ring', 'cost', 'much', 'dam', 'credit', 'crunch'],
#  ['got',
#   'home',
#   'bought',
#   'twiggi',
#   'toothbrush',
#   'promis',
#   'make',
#   'teeth',
#   'cleaner'],
#  ['thank',
#   'todd',
#   'enjoy',
#   'read',
#   'blog',
#   'littl',
#   'cheer',
#   'good',
#   'old',
#   'alfr',
#   'wallac',
#   'curiou',
#   'read',
#   'book'],
#  ['couldnt',
#   'come',
#   'see',
#   'southend',
#   'nd',
#   'couldnt',
#   'get',
#   'ticket',
#   'ill',
#   'come',
#   'see',
#   'solo',
#   'tour'],
#  ['need',
#   'help',
#   'twitter',
#   'world',
#   'orang',
#   'theraflu',
#   'pillsar',
#   'go',
#   'drowsi',
#   'non',
#   'drowsi'],
#  ['small', 'cant', 'choos'],
#  ['edit', 'pictur'],
#  ['thank',
#   'click',
#   'well',
#   'think',
#   'someth',
#   'wrong',
#   'still',
#   'visitor',
#   'mayb',
#   'need',
#   'reinstal',
#   'everyth'],
#  ['seper', 'yum', 'togeth', 'gross', 'sound'],
#  ['made', 'got', 'home', 'wango', 'tango', 'wonder', 'day'],
#  ['si', 'bueno', 'guess', 'entertain'],
#  ['dont',
#   'worri',
#   'babi',
#   'ill',
#   'eat',
#   'sum',
#   'cake',
#   'us',
#   'ill',
#   'hit',
#   'wen',
#   'get',
#   'back',
#   'bye',
#   'dont',
#   'eat',
#   'much',
#   'home'],
#  ['bake', 'cake', 'momma'],
#  ['know', 'want', 'left', 'home', 'weekend'],
#  ['suddenli', 'rememb', 'memori', 'ohhh', 'pleas'],
#  ['yeah', 'did', 'explain', 'everyth'],
#  ['think', 'mess', 'back', 'like', 'day'],
#  ['everyon', 'left', 'gone', 'bed'],
#  ['jean',
#   'awessome',
#   'cut',
#   'hurrr',
#   'give',
#   'massag',
#   'orr',
#   'alki',
#   'foodtour',
#   'yeaaah',
#   'ill',
#   'pray',
#   'ur',
#   'cousin'],
#  ['problem', 'finish', 'log', 'mass', 'hour', 'week', 'it', 'paid', 'pop'],
#  ['truesdal', 'lmao', 'mess', 'im', 'gonna', 'atl', 'week'],
#  ['tati', 'sent', 'emal', 'doll', 'get', 'it'],
#  ['said'],
#  ['lpz', 'yeah', 'text', 'me', 'wnat', 'go', 'car', 'broken'],
#  ['hehe', 'true', 'wonder', 'come'],
#  ['wanna',
#   'say',
#   'happi',
#   'mother',
#   'day',
#   'mom',
#   'includ',
#   'mine',
#   'love',
#   'mama'],
#  ['home', 'sweet', 'home', 'think', 'no', 'huaaaa'],
#  ['anywher', 'minda', 'long', 'superman', 'there', 'good', 'musical', 'sweet'],
#  ['extaci',
#   'laugh',
#   'loud',
#   'know',
#   'eric',
#   'wont',
#   'delet',
#   'you',
#   'peopl',
#   'dont',
#   'realli',
#   'know',
#   'never',
#   'talk',
#   'band'],
#  ['well', 'ill', 'lemon', 'ranch', 'you', 'me', 'though'],
#  ['much', 'asugar', 'btast', 'lord', 'put', 'ya', 'down', 'fun', 'way'],
#  ['watch', 'film', 'real', 'women', 'curv', 'good', 'film', 'middl', 'night'],
#  ['went',
#   'saw',
#   'fight',
#   'last',
#   'night',
#   'best',
#   'friend',
#   'great',
#   'chan',
#   'tatum',
#   'amaz'],
#  ['ill', 'tri', 'silli', 'silli', 'tweetdeck', 'mean'],
#  ['happi', 'mother', 'day', 'mom'],
#  ['new', 'supernatur', 'tonight'],
#  ['happi',
#   'birthday',
#   'happi',
#   'birthday',
#   'happi',
#   'birthday',
#   'happi',
#   'birthday',
#   'happi',
#   'birthday',
#   'mani',
#   'more'],
#  ['aint', 'lyk', 'othaa', 'gurrrrrl', 'dont', 'lyk', 'jona', 'brotherskristi'],
#  ['ouch', 'burnt', 'arm', 'grill'],
#  ['bed', 'church', 'morn', 'happi', 'mother', 'day'],
#  ['thank', 'prove', 'point'],
#  ['omg', 'fuck', 'site', 'follow', 'me'],
#  ['aww', 'chamber', 'callback', 'soo', 'emot'],
#  ['tan', 'emili', 'bad', 'prob', 'gonna', 'rain'],
#  ['maatt',
#   'havent',
#   'spoken',
#   'age',
#   'dudee',
#   'dont',
#   'forget',
#   'bout',
#   'ur',
#   'aussi',
#   'fan',
#   'lool',
#   'love',
#   'ya'],
#  ['pizza', 'go', 'sleep'],
#  ['marmey', 'want', 'cake', 'chocol'],
#  ['talk', 'anthoni', 'rapp', 'face', 'face'],
#  ['good',
#   'even',
#   'terri',
#   'miss',
#   'late',
#   'hope',
#   'life',
#   'good',
#   'you',
#   'wonder',
#   'even'],
#  ['softwar',
#   'use',
#   'design',
#   'site',
#   'cs',
#   'student',
#   'current',
#   'hard',
#   'code',
#   'everyth',
#   'fastest',
#   'way'],
#  ['laugh', 'loud', 'spongebob'],
#  ['beach', 'nanni', 'got', 'back', 'roast', 'iater', 'pud'],
#  ['happi', 'mother', 'day', 'tweet', 'mother'],
#  ['look', 'self', 'right', 'back'],
#  ['normal',
#   'dnt',
#   'sleep',
#   'like',
#   'cud',
#   'never',
#   'sleep',
#   'night',
#   'ur',
#   'entertain'],
#  ['ahh', 'im', 'love', 'he', 'theeee', 'best'],
#  ['ill',
#   'watch',
#   'soon',
#   'then',
#   'love',
#   'new',
#   'york',
#   'sweet',
#   'ill',
#   'lookout',
#   'that'],
#  ['oh', 'see', 'daili', 'life', 'shot', 'itll', 'interest', 'well'],
#  ['palm', 'pre', 'record', 'video'],
#  ['want', 'follow'],
#  ['miss', 'way', 'much', 'cnt', 'stop', 'think', 'nite', 'nite', 'folkkz'],
#  ['laugh', 'loud', 'yeah', 'forgot', 'tweetdeck', 'status', 'funni'],
#  ['wanna', 'better', 'alreadi'],
#  ['chill', 'day', 'parti', 'tomorrow'],
#  ['never', 'watch', 'mani', 'movi', 'one', 'night', 'mommi'],
#  ['cri', 'cuz', 'peopl', 'wont', 'follow', 'me'],
#  ['roxi', 'right', 'palmad', 'stuff', 'pretti', 'cool'],
#  ['im', 'homeon', 'friday', 'night', 'good'],
#  ['need', 'skott', 'right'],
#  ['haha', 'pretti', 'good', 'theyr', 'make', 'someth', 'chicken', 'yum'],
#  ['whove', 'notic', 'kate'],
#  ['great', 'say', 'im', 'old', 'all'],
#  ['love', 'book', 'read', 'host', 'amaz', 'storytel'],
#  ['thank', 'agre'],
#  ['wow',
#   'hate',
#   'stapl',
#   'right',
#   'now',
#   'majorli',
#   'thank',
#   'complet',
#   'fucktard',
#   'kill',
#   'product'],
#  ['milano',
#   'good',
#   'morn',
#   'alyssa',
#   'hope',
#   'great',
#   'wonder',
#   'day',
#   'today',
#   'im',
#   'happi',
#   'cuz',
#   'today',
#   'last',
#   'day',
#   'class',
#   'yay'],
#  ['tinker',
#   'opensourc',
#   'virtualbox',
#   'win',
#   'yet',
#   'wouldv',
#   'love',
#   'seen',
#   'hay',
#   'alway',
#   'unfortun',
#   'time',
#   'student'],
#  ['facebook', 'group', 'world', 'leader'],
#  ['guy',
#   'past',
#   'ok',
#   'sinc',
#   'iã',
#   'â½v',
#   'got',
#   'appart',
#   'caritã',
#   'â½',
#   'difficult',
#   'save',
#   'money'],
#  ['still', 'courthous', 'happi', 'job', 'sad', 'one'],
#  ['thank', 'kelli', 'mean', 'lot', 'figur', 'apt', 'thing', 'yet'],
#  ['happi', 'mother', 'day', 'mom'],
#  ['sowwi', 'lover'],
#  ['well',
#   'guess',
#   'mccafetast',
#   'like',
#   'cure',
#   'ur',
#   'crave',
#   'get',
#   'mcskillet',
#   'want'],
#  ['want', 'mont', 'cristo', 'sandwich', 'sooo', 'bad'],
#  ['love',
#   'day',
#   'sky',
#   'clear',
#   'bird',
#   'sing',
#   'stuck',
#   'offic',
#   'window',
#   'hour'],
#  ['everybodi', 'sick'],
#  ['gloomi',
#   'day',
#   'cant',
#   'stop',
#   'bliss',
#   'hope',
#   'ronaldo',
#   'score',
#   'derbi',
#   'match',
#   'today'],
#  ['wow', 'saw', 'tweet', 'proflow', 'fiasco', 'that', 'fun'],
#  ['absolut'],
#  ['awww',
#   'man',
#   'suck',
#   'big',
#   'tear',
#   'eye',
#   'look',
#   'way',
#   'give',
#   'someth',
#   'look',
#   'forward',
#   'too',
#   'nice',
#   'long',
#   'ride'],
#  ['concert', 'tonight', 'chackin', 'come', 'tomorrow'],
#  ['tire',
#   'climb',
#   'bed',
#   'fall',
#   'asleep',
#   'hope',
#   'weekend',
#   'fun',
#   'coupl',
#   'week',
#   'left'],
#  ['year', 'cant', 'catch', 'it', 'ny', 'till', 'oct'],
#  ['omg',
#   'tweet',
#   'sooo',
#   'late',
#   'sorri',
#   'miss',
#   'good',
#   'time',
#   'no',
#   'marri',
#   'still',
#   'great',
#   'friend'],
#  ['thank',
#   'you',
#   'afrin',
#   'nasal',
#   'spray',
#   'also',
#   'got',
#   'giant',
#   'teacup',
#   'tonight'],
#  ['drag',
#   'low',
#   'point',
#   'slowli',
#   'wine',
#   'assist',
#   'prob',
#   'sensibl',
#   'low',
#   'hit',
#   'often'],
#  ['look',
#   'like',
#   'rain',
#   'oh',
#   'well',
#   'give',
#   'chanc',
#   'work',
#   'new',
#   'crochet',
#   'pattern',
#   'work'],
#  ['dang',
#   'it',
#   'realli',
#   'look',
#   'like',
#   'sigh',
#   'min',
#   'shower',
#   'min',
#   'get',
#   'readi'],
#  ['back',
#   'kill',
#   'me',
#   'keep',
#   'drop',
#   'lowhop',
#   'got',
#   'someon',
#   'pick',
#   'back',
#   'tho',
#   'laugh',
#   'loud'],
#  ['dad',
#   'said',
#   'trip',
#   'uk',
#   'cancel',
#   'due',
#   'da',
#   'swine',
#   'flu',
#   'ooop',
#   'sorri',
#   'abang'],
#  ['man', 'sinus', 'realli', 'buggin', 'morn'],
#  ['look', 'like', 'diamond', 'ball'],
#  ['poor',
#   'ds',
#   'bed',
#   'fever',
#   'abl',
#   'walk',
#   'relay',
#   'life',
#   'tonight',
#   'feel',
#   'bad',
#   'him',
#   'he',
#   'sad'],
#  ['happi', 'mother', 'day', 'beauti'],
#  ['cant', 'figur', 'listen', 'internet'],
#  ['twitter', 'trippin', 'right', 'pic'],
#  ['actual', 'progress', 'studi', 'today'],
#  ['new',
#   'work',
#   'pictur',
#   'taken',
#   'today',
#   'hate',
#   'it',
#   'look',
#   'much',
#   'like'],
#  ['good', 'morn', 'tweepl', 'sun', 'to'],
#  ['fell',
#   'holdin',
#   'kale',
#   'hand',
#   'todayi',
#   'hurt',
#   'foot',
#   'bruis',
#   'forehead',
#   'im',
#   'klutz'],
#  ['good', 'morn', 'everbodi'],
#  ['thank', 'tri', 'keep', 'chin', 'up', 'ouch'],
#  ['would',
#   'ideal',
#   'howevernow',
#   'dont',
#   'see',
#   'leav',
#   'gonna',
#   'take',
#   'rain',
#   'check'],
#  ['bad', 'day'],
#  ['leav',
#   'soon',
#   'kansa',
#   'citi',
#   'take',
#   'stuff',
#   'day',
#   'live',
#   'carthag',
#   'left'],
#  ...]

# %%
model = gensim.models.Word2Vec(window=10, min_count=2, workers=4)

# %%
model.build_vocab(corpus)

# %%
model.train(corpus, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (669481, 795815)

# %%
model.wv.most_similar('thank')
# Out:
# [('appreci', 0.9943791627883911),
#  ('tell', 0.9930616021156311),
#  ('hi', 0.9917406439781189),
#  ('her', 0.9914353489875793),
#  ('ace', 0.990988552570343),
#  ('us', 0.9906764030456543),
#  ('twitpic', 0.9905674457550049),
#  ('luv', 0.9903810024261475),
#  ('hey', 0.9902838468551636),
#  ('and', 0.9902411103248596)]

# %%
model.wv.most_similar('hi')
# Out:
# [('said', 0.9990267157554626),
#  ('song', 0.9989479780197144),
#  ('ps', 0.9988647103309631),
#  ('tell', 0.9988498091697693),
#  ('teach', 0.998753011226654),
#  ('luv', 0.9987430572509766),
#  ('share', 0.9986289143562317),
#  ('perfect', 0.9986187815666199),
#  ('sent', 0.9985387325286865),
#  ('congrat', 0.998472273349762)]

# %%
model.wv.similarity('hi','hey')
# Out:
# 0.9981058

# %%
model.wv.index_to_key
# Out:
# ['day',
#  'go',
#  'get',
#  'good',
#  'work',
#  'love',
#  'like',
#  'today',
#  'got',
#  'one',
#  'cant',
#  'want',
#  'thank',
#  'happi',
#  'miss',
#  'know',
#  'back',
#  'realli',
#  'see',
#  'feel',
#  'think',
#  'im',
#  'eye',
#  'laugh',
#  'that',
#  'night',
#  'mother',
#  'hope',
#  'make',
#  'tear',
#  'new',
#  'well',
#  'home',
#  'look',
#  'it',
#  'loud',
#  'need',
#  'oh',
#  'still',
#  'much',
#  'great',
#  'watch',
#  'you',
#  'wish',
#  'come',
#  'me',
#  'morn',
#  'last',
#  'twitter',
#  'fun',
#  'week',
#  'haha',
#  'ill',
#  'tomorrow',
#  'say',
#  'tri',
#  'wait',
#  'sad',
#  'would',
#  'thing',
#  'friend',
#  'tonight',
#  'bad',
#  'sleep',
#  'follow',
#  'way',
#  'sorri',
#  'right',
#  'now',
#  'nice',
#  'mom',
#  'better',
#  'yeah',
#  'weekend',
#  'gonna',
#  'take',
#  'though',
#  'could',
#  'ive',
#  'start',
#  'peopl',
#  'show',
#  'even',
#  'bed',
#  'hour',
#  'next',
#  'there',
#  'time',
#  'hate',
#  'tweet',
#  'dont',
#  'school',
#  'play',
#  'guy',
#  'too',
#  'best',
#  'awesom',
#  'final',
#  'girl',
#  'call',
#  'suck',
#  'littl',
#  'movi',
#  'long',
#  'soon',
#  'use',
#  'let',
#  'hey',
#  'live',
#  'year',
#  'ok',
#  'everyon',
#  'never',
#  'tire',
#  'first',
#  'cool',
#  'sure',
#  'up',
#  'ye',
#  'us',
#  'talk',
#  'done',
#  'sick',
#  'alway',
#  'may',
#  'ur',
#  'life',
#  'find',
#  'pleas',
#  'phone',
#  'rain',
#  'head',
#  'keep',
#  'alreadi',
#  'hurt',
#  'anoth',
#  'wanna',
#  'man',
#  'lot',
#  'bore',
#  'eat',
#  'someth',
#  'lol',
#  'read',
#  'hous',
#  'old',
#  'enjoy',
#  'song',
#  'ever',
#  'guess',
#  'thought',
#  'friday',
#  'went',
#  'made',
#  'pretti',
#  'mean',
#  'yet',
#  'readi',
#  'help',
#  'yay',
#  'here',
#  'leav',
#  'check',
#  'mayb',
#  'again',
#  'bit',
#  'monday',
#  'left',
#  'give',
#  'big',
#  'amaz',
#  'star',
#  'listen',
#  'out',
#  'away',
#  'late',
#  'someon',
#  'finish',
#  'hard',
#  'also',
#  'excit',
#  'what',
#  'job',
#  'kid',
#  'sound',
#  'wow',
#  'tell',
#  'hot',
#  'noth',
#  'actual',
#  'saw',
#  'parti',
#  'run',
#  'omg',
#  'th',
#  'happen',
#  'stop',
#  'am',
#  'wonder',
#  'world',
#  'later',
#  'said',
#  'earli',
#  'gone',
#  'put',
#  'glad',
#  'no',
#  'car',
#  'babi',
#  'move',
#  'pic',
#  'end',
#  'hi',
#  'do',
#  'hear',
#  'he',
#  'two',
#  'birthday',
#  'yesterday',
#  'sun',
#  'stuff',
#  'weather',
#  'ugh',
#  'music',
#  'around',
#  'game',
#  'drink',
#  'meet',
#  'ya',
#  'anyth',
#  'sinc',
#  'seem',
#  'till',
#  'poor',
#  'id',
#  'found',
#  'god',
#  'lost',
#  'cri',
#  'book',
#  'must',
#  'post',
#  'gotta',
#  'caus',
#  'might',
#  'buy',
#  'forward',
#  'welcom',
#  'aww',
#  'all',
#  'far',
#  'summer',
#  'stupid',
#  'shop',
#  'beauti',
#  'almost',
#  'stay',
#  'believ',
#  'famili',
#  'mine',
#  'hair',
#  'money',
#  'cute',
#  'funni',
#  'luck',
#  'mani',
#  'pictur',
#  'write',
#  'busi',
#  'coffe',
#  'drive',
#  'video',
#  'month',
#  'sunday',
#  'least',
#  'tho',
#  'chang',
#  'class',
#  'lunch',
#  'total',
#  'cold',
#  'plan',
#  'mum',
#  'everyth',
#  'die',
#  'food',
#  'dinner',
#  'turn',
#  'place',
#  'sit',
#  'exam',
#  'fail',
#  'name',
#  'dog',
#  'close',
#  'anyon',
#  'without',
#  'ask',
#  'idea',
#  'boy',
#  'free',
#  'clean',
#  'sweet',
#  'probabl',
#  'break',
#  'them',
#  'woke',
#  'photo',
#  'dream',
#  'outsid',
#  'took',
#  'dad',
#  'fan',
#  'ha',
#  'okay',
#  'hell',
#  'send',
#  'seen',
#  'enough',
#  'person',
#  'didnt',
#  'anymor',
#  'whole',
#  'real',
#  'updat',
#  'mommi',
#  'hit',
#  'quit',
#  'room',
#  'everi',
#  'aw',
#  'rock',
#  'awww',
#  'hug',
#  'minut',
#  'vote',
#  'part',
#  'tv',
#  'kinda',
#  'sooo',
#  'headach',
#  'wake',
#  'problem',
#  'hahaha',
#  'holiday',
#  'offic',
#  'kind',
#  'hang',
#  'goodnight',
#  'full',
#  'rememb',
#  'ago',
#  'were',
#  'mind',
#  'trip',
#  'els',
#  'came',
#  'pain',
#  'dude',
#  'wrong',
#  'war',
#  'stuck',
#  'super',
#  'moment',
#  'in',
#  'iphon',
#  'boo',
#  'on',
#  'crazi',
#  'blog',
#  'walk',
#  'theyr',
#  'awak',
#  'hello',
#  'â½',
#  'repli',
#  'email',
#  'suppos',
#  'kill',
#  'win',
#  'so',
#  'saturday',
#  'anyway',
#  'pm',
#  'worri',
#  'ticket',
#  'set',
#  'text',
#  'cat',
#  'news',
#  'wear',
#  'abl',
#  'onlin',
#  'internet',
#  'face',
#  'comput',
#  'forgot',
#  'sometim',
#  'either',
#  'broke',
#  'instead',
#  'told',
#  'trek',
#  'learn',
#  'open',
#  'messag',
#  'word',
#  'off',
#  'soo',
#  'wont',
#  'alon',
#  'her',
#  'rest',
#  'heard',
#  'bank',
#  'figur',
#  'catch',
#  'card',
#  'lil',
#  'ice',
#  'nite',
#  'park',
#  'facebook',
#  'pick',
#  'perfect',
#  'bring',
#  'concert',
#  'ah',
#  'interest',
#  'min',
#  'cuz',
#  'spend',
#  'dead',
#  'lucki',
#  'top',
#  'brother',
#  'save',
#  'studi',
#  'hungri',
#  'site',
#  'to',
#  'fine',
#  'is',
#  'bless',
#  'test',
#  'la',
#  'date',
#  'shower',
#  'half',
#  'link',
#  'care',
#  'yea',
#  'st',
#  'ladi',
#  'favorit',
#  'true',
#  'goe',
#  'danc',
#  'til',
#  'youtub',
#  'second',
#  'point',
#  'tea',
#  'window',
#  'wed',
#  'train',
#  'relax',
#  'hehe',
#  'fall',
#  'short',
#  'beach',
#  'sing',
#  'down',
#  'tour',
#  'him',
#  'pack',
#  'hand',
#  'differ',
#  'cut',
#  'bday',
#  'mr',
#  'definit',
#  'sigh',
#  'heart',
#  'then',
#  'reason',
#  'breakfast',
#  'account',
#  'coupl',
#  'fix',
#  'less',
#  'bought',
#  'nd',
#  'yall',
#  'cours',
#  'list',
#  'share',
#  'chocol',
#  'not',
#  'goin',
#  'forget',
#  'join',
#  'thi',
#  'soooo',
#  'bout',
#  'smile',
#  'june',
#  'page',
#  'ride',
#  'finger',
#  'more',
#  'cake',
#  'season',
#  'asleep',
#  'agre',
#  'nap',
#  'due',
#  'revis',
#  'flu',
#  'water',
#  'sister',
#  'cheer',
#  'dear',
#  'complet',
#  'episod',
#  'high',
#  'togeth',
#  'garden',
#  'knew',
#  'download',
#  'citi',
#  'comment',
#  'present',
#  'sign',
#  'sore',
#  'fair',
#  'block',
#  'load',
#  'chanc',
#  'red',
#  'cook',
#  'visit',
#  'decid',
#  'pass',
#  'sadli',
#  'cream',
#  'sunni',
#  'store',
#  'gave',
#  'yep',
#  'graduat',
#  'babe',
#  'usual',
#  'answer',
#  'afternoon',
#  'aint',
#  'mad',
#  'past',
#  'realiz',
#  'everybodi',
#  'ipod',
#  'xd',
#  'jealou',
#  'three',
#  'uk',
#  'chat',
#  'plu',
#  'special',
#  'mess',
#  'and',
#  'congrat',
#  'huge',
#  'order',
#  'laptop',
#  'pay',
#  'album',
#  'fb',
#  'offici',
#  'hr',
#  'shot',
#  'where',
#  'dress',
#  'doesnt',
#  'town',
#  'parent',
#  'side',
#  'add',
#  'stori',
#  'drop',
#  'mile',
#  'ppl',
#  'bye',
#  'warm',
#  'london',
#  'apart',
#  'fast',
#  'ahh',
#  'unfortun',
#  'how',
#  'number',
#  'googl',
#  'fell',
#  'age',
#  'upload',
#  'mood',
#  'except',
#  'jona',
#  'other',
#  'beat',
#  'sunshin',
#  'upset',
#  'forev',
#  'blue',
#  'pizza',
#  'line',
#  'ps',
#  'spent',
#  'yr',
#  'horribl',
#  'beer',
#  'leg',
#  'band',
#  'broken',
#  'scare',
#  'white',
#  'mama',
#  'easi',
#  'app',
#  'meant',
#  'black',
#  'gym',
#  'bet',
#  'sat',
#  'gut',
#  'arriv',
#  'nope',
#  'rather',
#  'understand',
#  'worst',
#  'fli',
#  'camera',
#  'ass',
#  'along',
#  'son',
#  'appreci',
#  'stress',
#  'absolut',
#  'havent',
#  'annoy',
#  'disappoint',
#  'chill',
#  'worth',
#  'lay',
#  'cannot',
#  'bu',
#  'slow',
#  'stand',
#  'bum',
#  'project',
#  'english',
#  'becom',
#  'cancel',
#  'over',
#  'gift',
#  'da',
#  'ad',
#  'compani',
#  'invit',
#  'earlier',
#  'question',
#  'shoe',
#  'bike',
#  'celebr',
#  'especi',
#  'remind',
#  'possibl',
#  'depress',
#  'appar',
#  'stomach',
#  'wash',
#  'surpris',
#  'fantast',
#  'shirt',
#  'yum',
#  'whi',
#  'cover',
#  'be',
#  'yummi',
#  'rip',
#  'dm',
#  'safe',
#  'notic',
#  'cousin',
#  'green',
#  'wors',
#  'appl',
#  'co',
#  'insid',
#  'bc',
#  'record',
#  'ahhh',
#  'lose',
#  'bgt',
#  'ran',
#  'hun',
#  'but',
#  'shame',
#  'note',
#  'burn',
#  'cup',
#  'ate',
#  'light',
#  'boyfriend',
#  'team',
#  'fact',
#  'count',
#  'club',
#  'hmm',
#  'film',
#  'prob',
#  'chees',
#  'sent',
#  'none',
#  'expect',
#  'sleepi',
#  'support',
#  'the',
#  'serious',
#  'return',
#  'piss',
#  'fight',
#  'colleg',
#  'chicken',
#  'dang',
#  'flight',
#  'moon',
#  'lone',
#  'whatev',
#  'screen',
#  'ohh',
#  'wa',
#  'version',
#  'matter',
#  'swine',
#  'hubbi',
#  'mate',
#  'em',
#  'weird',
#  'cross',
#  'idk',
#  'throat',
#  'case',
#  'confus',
#  'singl',
#  'your',
#  'air',
#  'isnt',
#  'bag',
#  'math',
#  'snl',
#  'kick',
#  'group',
#  'momma',
#  'web',
#  'feet',
#  'deal',
#  'behind',
#  'she',
#  'etc',
#  'sold',
#  'traffic',
#  'sort',
#  'paper',
#  'cd',
#  'touch',
#  'men',
#  'mac',
#  'homework',
#  'low',
#  'lie',
#  'lame',
#  'btw',
#  'current',
#  'iã',
#  'hold',
#  'bro',
#  'crash',
#  'wine',
#  'radio',
#  'small',
#  'hannah',
#  'dvd',
#  'prom',
#  'woo',
#  'near',
#  'david',
#  'wife',
#  'doctor',
#  'dark',
#  'longer',
#  'cloth',
#  'daughter',
#  'event',
#  'pray',
#  'bodi',
#  'guitar',
#  'anim',
#  'drunk',
#  'arm',
#  'â½m',
#  'cooki',
#  'lazi',
#  'twilight',
#  'hospit',
#  'impress',
#  'myself',
#  'exactli',
#  'middl',
#  'puppi',
#  'websit',
#  'mention',
#  'manag',
#  'random',
#  'travel',
#  'quick',
#  'who',
#  'raini',
#  'copi',
#  'pool',
#  'starbuck',
#  'huh',
#  'quiet',
#  'chillin',
#  'servic',
#  'thursday',
#  'swim',
#  'ooh',
#  'talent',
#  'alot',
#  'tom',
#  'contact',
#  'suggest',
#  'fuck',
#  'memori',
#  'via',
#  'church',
#  'slept',
#  'tuesday',
#  'round',
#  'twit',
#  'machin',
#  'voic',
#  'normal',
#  'edit',
#  'tummi',
#  'imagin',
#  'track',
#  'jump',
#  'roll',
#  'profil',
#  'fit',
#  'pull',
#  'sale',
#  'itll',
#  'fish',
#  'proud',
#  'vega',
#  'joke',
#  'convers',
#  'pop',
#  'peac',
#  'box',
#  'review',
#  'gorgeou',
#  'bug',
#  'lesson',
#  'issu',
#  'wat',
#  'bird',
#  'shoot',
#  'hahah',
#  'speak',
#  'nobodi',
#  'juli',
#  'felt',
#  'key',
#  'sexi',
#  'goodby',
#  'with',
#  'releas',
#  'although',
#  'ball',
#  'have',
#  'fri',
#  'myspac',
#  'french',
#  'egg',
#  'expens',
#  'floor',
#  'bbq',
#  'promis',
#  'shall',
#  'addict',
#  'blackberri',
#  'power',
#  'terribl',
#  'doubl',
#  'tip',
#  'congratul',
#  'inde',
#  'rd',
#  'pc',
#  'simpl',
#  'student',
#  'taken',
#  'public',
#  'interview',
#  'luv',
#  'flower',
#  'paint',
#  'american',
#  'product',
#  'heat',
#  'hilari',
#  'met',
#  'ton',
#  'tha',
#  'about',
#  'code',
#  'john',
#  'marri',
#  'connect',
#  'design',
#  'mobil',
#  'xoxo',
#  'street',
#  'teach',
#  'si',
#  'tast',
#  'vid',
#  'state',
#  'jack',
#  'bottl',
#  'session',
#  'miley',
#  'plane',
#  'milk',
#  'ignor',
#  'fill',
#  'screw',
#  'road',
#  'joe',
#  'experi',
#  'eh',
#  'justin',
#  'wast',
#  'fav',
#  'charg',
#  'bar',
#  'vacat',
#  'attempt',
#  'bare',
#  'mmm',
#  'freak',
#  'fever',
#  'fam',
#  'stick',
#  'recommend',
#  'daddi',
#  'direct',
#  'ouch',
#  'scari',
#  'social',
#  'futur',
#  'gig',
#  'drag',
#  'afraid',
#  'extra',
#  'foot',
#  'young',
#  'quot',
#  'yo',
#  'yup',
#  'deserv',
#  'gettin',
#  'ju',
#  'coz',
#  'sam',
#  'door',
#  'jon',
#  'did',
#  'paid',
#  'avail',
#  'race',
#  'nah',
#  'piec',
#  'ach',
#  'act',
#  'search',
#  'smell',
#  ...]

# %%
# import googleapiclient.discovery
# import googleapiclient.errors

# %%
# api_service_name = "youtube"
# api_version = "v3"
# DEVELOPER_KEY = "AIzaSyDK_z4DwCkXkpieD9UyWlaQyo4vxE8w57I"

# %%
# youtube = googleapiclient.discovery.build(
#     api_service_name, api_version, developerKey=DEVELOPER_KEY
# )

# %%
# request = youtube.commentThreads().list(
#     part="snippet",
#     videoId="-GJgqIJsTME",
#     maxResults=100
# )

# %%
# response = request.execute()

# %%
# response['items'][0]

# %%
# for item in response['items']:
#   print(item['snippet']['topLevelComment']['snippet']['textDisplay'])

# %%
# comment_list = []
# for item in response['items']:
#   comment = item['snippet']['topLevelComment']['snippet']
#   comment_list.append([
#       comment['textDisplay'],
#       comment['likeCount']
#   ])

# %%
# df = pd.DataFrame(comment_list, columns=['comment', 'likeCount'])

# %%
# df.head()

# %%
# df

# %%
# while(1 == 1):
#   try:
#     nextPageToken = response['nextPageToken']
#   except KeyError:
#     break
#   nextPageToken = response['nextPageToken']

#   nextRequest = youtube.commentThreads().list(
#       part="snippet",
#       videoId="-GJgqIJsTME",
#       maxResults=100,
#       pageToken=nextPageToken
#   )
#   response = nextRequest.execute()

#   for item in response['items']:
#     comment = item['snippet']['topLevelComment']['snippet']
#     comment_list.append([
#         comment['textDisplay'],
#         comment['likeCount']
#     ])
# df = pd.DataFrame(comment_list, columns=['comment', 'likeCount'])

# %%
# df

# %%
# df.head()

# %%
# df.info()

# %%
# df.sample(5)

# %% [markdown]
# ### Spelling correction

# %%
# from textblob import TextBlob

# %%
# def spell_correction(text):
#   textBlb = TextBlob(text)
#   return textBlb.correct().string

# %%
# text = "ceertain connditionas duriing serveal ggenerations aree moodified in the saame maner"
# spell_correction(text)

# %% [markdown]
# ### Calm down!!! It will take time. Sip some water.

# %%
# from concurrent.futures import ThreadPoolExecutor

# %%
# # Function to apply in parallel
# def parallel_apply(df_column, func):
#     with ThreadPoolExecutor() as executor:
#         results = list(executor.map(func, df_column))
#     return results

# %%
# parallel_apply(x_train['comment'], spell_correction)

# %%
# x_train['comment'] = x_train['comment'].apply(spell_correction)
# x_test['comment'] = x_test['comment'].apply(spell_correction)
